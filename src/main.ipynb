# %%
pip install -r requirements.txt --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import math
import os
import pandas as pd
import torch
import time as time
from omegaconf import OmegaConf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

# %%
pd.set_option('display.max_columns', None)

# %%
# Read pickles from the path specified in config.dest_file
config_path = "config_server.yaml"  # Replace with the path to your config file
config = OmegaConf.load(config_path)
df_encoded_path = os.path.join(config.dest_file, "df_encoded.csv")
# Load the DataFrame from the CSV file
df = pd.read_csv("df_encoded.csv")

# %%
# keep only 20% of the data for faster computation
df_small = df.sample(frac=1.0, random_state=42).reset_index(drop=False)

# %%
df_small.describe()
# Out:
#                index  surfaceProcessingLocationCavity      hotRunner  \
# count  164148.000000                    164148.000000  164148.000000
# mean    82073.500000                         3.000000       0.195409
# std     47385.590331                         0.554905       0.396516
# min         0.000000                         2.000000       0.000000
# 25%     41036.750000                         3.000000       0.000000
# 50%     82073.500000                         3.000000       0.000000
# 75%    123110.250000                         3.000000       0.000000
# max    164147.000000                         4.000000       1.000000
#
#        hotRunnerCost  manufacturingCost  mouldValidationCost     designTime  \
# count  164148.000000      164148.000000        164148.000000  164148.000000
# mean    15862.270634       36722.073982          1606.586739      51.724541
# std     10592.036270       12479.432960           505.081843      21.184073
# min     10000.000000       25000.000000          1500.000000      40.000000
# 25%     10000.000000       25000.000000          1500.000000      40.000000
# 50%     10000.000000       40000.000000          1500.000000      40.000000
# 75%     25000.000000       55000.000000          1500.000000      70.000000
# max     40000.000000       55000.000000          4500.000000     100.000000
#
#        hourlyDesignCost  removedChassis  weightChassisProcessed  \
# count     164148.000000   164148.000000             164148.0000
# mean          50.532934        0.163086                  6.6725
# std            2.776695        0.024592                  0.0000
# min           50.000000        0.150000                  6.6725
# 25%           50.000000        0.150000                  6.6725
# 50%           50.000000        0.150000                  6.6725
# 75%           50.000000        0.180000                  6.6725
# max           65.000000        0.225000                  6.6725
#
#        surfaceProcessingLocationChassis  removedCavity  numberOfCavities  \
# count                     164148.000000  164148.000000     164148.000000
# mean                           0.769793       0.308290          2.740917
# std                            1.186966       0.037572          6.279052
# min                            0.000000       0.300000          1.000000
# 25%                            0.000000       0.300000          1.000000
# 50%                            0.000000       0.300000          1.000000
# 75%                            2.000000       0.300000          1.000000
# max                            3.000000       0.500000         32.000000
#
#        weightCavityProcessed   weightMould  totalTransportationPercentage  \
# count          164148.000000  1.641480e+05                       164148.0
# mean                0.005495  6.677995e+00                          100.0
# std                 0.000000  3.552725e-15                            0.0
# min                 0.005495  6.677995e+00                          100.0
# 25%                 0.005495  6.677995e+00                          100.0
# 50%                 0.005495  6.677995e+00                          100.0
# 75%                 0.005495  6.677995e+00                          100.0
# max                 0.005495  6.677995e+00                          100.0
#
#        percentageAircraft  percentageLorry  percentageTrain  percentageShip  \
# count            164148.0         164148.0         164148.0        164148.0
# mean                  5.0             25.0             40.0            30.0
# std                   0.0              0.0              0.0             0.0
# min                   5.0             25.0             40.0            30.0
# 25%                   5.0             25.0             40.0            30.0
# 50%                   5.0             25.0             40.0            30.0
# 75%                   5.0             25.0             40.0            30.0
# max                   5.0             25.0             40.0            30.0
#
#        totalDistance  transportCost  injectedMaterial_product  \
# count  164148.000000       164148.0             164148.000000
# mean     1133.808514         4000.0                  3.455528
# std      2229.091505            0.0                  1.700838
# min        50.000000         4000.0                  0.000000
# 25%        50.000000         4000.0                  3.000000
# 50%        50.000000         4000.0                  3.000000
# 75%        50.000000         4000.0                  3.000000
# max      6850.000000         4000.0                  8.000000
#
#        injectedMaterialCost  percentageRecycledMaterial       maxDepth  \
# count         164148.000000               164148.000000  164148.000000
# mean               2.275922                    0.461194      19.336300
# std                2.623105                    0.498493      29.477817
# min                1.000000                    0.000000       5.000000
# 25%                1.000000                    0.000000       5.000000
# 50%                1.000000                    0.000000       5.000000
# 75%                1.000000                    1.000000       5.000000
# max                9.000000                    1.000000      95.000000
#
#        maxWallThickness  productVolume  materozzaVolume  nAnniProduzione  \
# count     164148.000000  164148.000000    164148.000000         164148.0
# mean           1.319736       9.781782         0.319078              1.0
# std            0.732969       9.831097         0.466121              0.0
# min            1.000000       5.000000         0.000000              1.0
# 25%            1.000000       5.000000         0.000000              1.0
# 50%            1.000000       5.000000         0.000000              1.0
# 75%            1.000000       5.000000         1.000000              1.0
# max            3.000000      35.000000         1.000000              1.0
#
#        nProdottiAnno  materialDensity      tolerance  surfaceFinishing  \
# count  164148.000000    164148.000000  164148.000000     164148.000000
# mean     5381.814874         0.001102       0.147477          0.174690
# std     15494.806796         0.000140       0.681254          0.768119
# min         1.000000         0.000920       0.000000          0.000000
# 25%         1.000000         0.001050       0.000000          0.000000
# 50%         1.000000         0.001050       0.000000          0.000000
# 75%         1.000000         0.001050       0.000000          0.000000
# max     50001.000000         0.001550       4.000000          4.000000
#
#        cycleTime  machineCycleTime  maintenanceCost  productionCost  \
# count   164148.0     164148.000000    164148.000000   164148.000000
# mean       360.0         14.347540     10185.344933       21.585642
# std          0.0         11.216855      6239.503454       11.208630
# min        360.0         10.000000      8000.000000       12.000000
# 25%        360.0         10.000000      8000.000000       12.000000
# 50%        360.0         10.000000      8000.000000       14.000000
# 75%        360.0         10.000000      8000.000000       30.000000
# max        360.0         50.000000     28000.000000       43.000000
#
#        injectedMaterial_materozza  injectionMouldingProcess  memtiEngineValue  \
# count               164148.000000             164148.000000          164148.0
# mean                     3.501060                  2.076979               0.0
# std                      1.647026                  0.525674               0.0
# min                      0.000000                  1.000000               0.0
# 25%                      3.000000                  2.000000               0.0
# 50%                      3.000000                  2.000000               0.0
# 75%                      3.000000                  2.000000               0.0
# max                      8.000000                  3.000000               0.0
#
#           steelPrice  runnersType  mouldMaterialName    machineName  \
# count  164148.000000     164148.0      164148.000000  164148.000000
# mean        0.426347          1.0           5.818901       9.061274
# std         1.047509          0.0           1.404725       4.282591
# min         0.000000          1.0           2.000000       2.000000
# 25%         0.000000          1.0           6.000000       7.000000
# 50%         0.000000          1.0           6.000000       7.000000
# 75%         0.000000          1.0           6.000000      11.000000
# max         3.000000          1.0           9.000000      19.000000
#
#        EUUSMacchina     CNMacchina  gateDiameter      setupTime  warmupTime  \
# count  164148.00000  164148.000000      164148.0  164148.000000    164148.0
# mean        5.43275       4.115469           1.0      41.896764        30.0
# std         3.29176       0.933774           0.0      38.959314         0.0
# min         0.00000       1.000000           1.0      15.000000        30.0
# 25%         4.00000       4.000000           1.0      15.000000        30.0
# 50%         4.00000       4.000000           1.0      15.000000        30.0
# 75%         6.00000       4.000000           1.0      65.000000        30.0
# max        14.00000       9.000000           1.0     115.000000        30.0
#
#        deliveryVolume  deliveryPeriod  mouldDesignCostDisplay  mouldTotalCost  \
# count   164148.000000   164148.000000                164148.0        164148.0
# mean      6594.545654        3.644126                  2000.0         38500.0
# std      16912.852510        4.686030                     0.0             0.0
# min         10.000000        2.000000                  2000.0         38500.0
# 25%         10.000000        2.000000                  2000.0         38500.0
# 50%         10.000000        2.000000                  2000.0         38500.0
# 75%         10.000000        2.000000                  2000.0         38500.0
# max      60010.000000       17.000000                  2000.0         38500.0
#
#                 Cost  human health - photochemical oxidation  \
# count  164148.000000                           164148.000000
# mean    66584.271435                                0.000040
# std     15482.078690                                0.000101
# min     40493.360588                                0.000004
# 25%     50506.788801                                0.000004
# 50%     65493.520938                                0.000005
# 75%     80493.360588                                0.000005
# max    117993.360588                                0.000341
#
#        ecosystem quality - terrestrial ecotoxicity  \
# count                                164148.000000
# mean                                      0.003328
# std                                       0.005769
# min                                       0.000804
# 25%                                       0.000857
# 50%                                       0.000993
# 75%                                       0.002188
# max                                       0.023920
#
#        resources - mineral extraction  resources - non-renewable energy  \
# count                   164148.000000                     164148.000000
# mean                         0.000024                          0.030269
# std                          0.000017                          0.080793
# min                          0.000018                          0.001357
# 25%                          0.000018                          0.001646
# 50%                          0.000018                          0.002434
# 75%                          0.000019                          0.003269
# max                          0.000089                          0.303884
#
#        ecosystem quality - terrestrial acidification & nutrification  \
# count                                      164148.000000
# mean                                            0.000185
# std                                             0.000451
# min                                             0.000022
# 25%                                             0.000024
# 50%                                             0.000030
# 75%                                             0.000036
# max                                             0.001755
#
#        resources - total  human health - ionising radiation  \
# count      164148.000000                      164148.000000
# mean            0.030294                           0.006191
# std             0.080809                           0.015016
# min             0.001374                           0.000561
# 25%             0.001664                           0.000737
# 50%             0.002452                           0.000800
# 75%             0.003287                           0.001735
# max             0.303972                           0.073156
#
#        human health - respiratory effects (inorganics)  human health - total  \
# count                                    164148.000000         164148.000000
# mean                                          0.014077              0.023236
# std                                           0.031402              0.051850
# min                                           0.002580              0.003998
# 25%                                           0.002760              0.004376
# 50%                                           0.003210              0.005363
# 75%                                           0.003723              0.006420
# max                                           0.127809              0.222702
#
#        human health - human toxicity  ecosystem quality - aquatic ecotoxicity  \
# count                  164148.000000                            164148.000000
# mean                        0.002927                                 0.000106
# std                         0.005354                                 0.000233
# min                         0.000852                                 0.000016
# 25%                         0.000895                                 0.000017
# 50%                         0.001115                                 0.000019
# 75%                         0.001286                                 0.000041
# max                         0.021389                                 0.000887
#
#        climate change - climate change  human health - ozone layer depletion  \
# count                    164148.000000                          1.641480e+05
# mean                          0.019277                          1.373095e-06
# std                           0.048485                          3.047302e-06
# min                           0.001819                          1.373808e-07
# 25%                           0.002012                          1.544478e-07
# 50%                           0.002502                          2.213792e-07
# 75%                           0.003030                          3.643282e-07
# max                           0.184725                          1.253427e-05
#
#        ecosystem quality - land occupation  climate change - total  \
# count                        164148.000000           164148.000000
# mean                              0.000173                0.019277
# std                               0.000378                0.048485
# min                               0.000032                0.001819
# 25%                               0.000034                0.002012
# 50%                               0.000043                0.002502
# 75%                               0.000051                0.003030
# max                               0.001701                0.184725
#
#        ecosystem quality - total
# count              164148.000000
# mean                    0.003792
# std                     0.006825
# min                     0.000873
# 25%                     0.000931
# 50%                     0.001105
# 75%                     0.002317
# max                     0.028259

# %%
feature_column = [
       'surfaceProcessingLocationCavity', 'hotRunner', 'hotRunnerCost',
       'manufacturingCost', 'mouldValidationCost', 'designTime',
       'hourlyDesignCost', 'removedChassis', 'weightChassisProcessed',
       'surfaceProcessingLocationChassis', 'removedCavity', 'numberOfCavities',
       'weightCavityProcessed', 'weightMould', 'totalTransportationPercentage',
       'percentageAircraft', 'percentageLorry', 'percentageTrain',
       'percentageShip', 'totalDistance', 'transportCost',
       'injectedMaterial_product', 'injectedMaterialCost',
       'percentageRecycledMaterial', 'maxDepth', 'maxWallThickness',
       'productVolume', 'materozzaVolume', 'nAnniProduzione', 'nProdottiAnno',
       'materialDensity', 'tolerance', 'surfaceFinishing', 'cycleTime',
       'machineCycleTime', 'maintenanceCost', 'productionCost',
       'injectedMaterial_materozza', 'injectionMouldingProcess',
       'memtiEngineValue', 'steelPrice', 'runnersType', 'mouldMaterialName',
       'machineName', 'EUUSMacchina', 'CNMacchina', 'gateDiameter',
       'setupTime', 'warmupTime', 'deliveryVolume', 'deliveryPeriod',
       'mouldDesignCostDisplay', 'mouldTotalCost']

target_column = ['Cost',
       'human health - photochemical oxidation',
       'ecosystem quality - terrestrial ecotoxicity',
       'resources - mineral extraction', 'resources - non-renewable energy',
       'ecosystem quality - terrestrial acidification & nutrification',
       'resources - total', 'human health - ionising radiation',
       'human health - respiratory effects (inorganics)',
       'human health - total', 'human health - human toxicity',
       'ecosystem quality - aquatic ecotoxicity',
       'climate change - climate change',
       'human health - ozone layer depletion',
       'ecosystem quality - land occupation', 'climate change - total',
       'ecosystem quality - total']

# %% [markdown]
# From the above table, we know hat most of the target variables having distance correlation=1 are redundant or used for deriving the final variables. Hence it is good to eliminate them and keep only four ['human health - total', 'ecosystem quality - total', 'resources - total', 'Cost']

# %%
selected_features= input_variables= ['surfaceProcessingLocationCavity', 'hotRunner',
'hotRunnerCost','manufacturingCost', 'mouldValidationCost',
'designTime','hourlyDesignCost', 'removedChassis', 'weightChassisProcessed',
'surfaceProcessingLocationChassis', 'removedCavity', 'numberOfCavities',
'weightCavityProcessed', 'weightMould',
'totalTransportationPercentage','percentageAircraft', 'percentageLorry', 'percentageTrain','percentageShip', 'totalDistance',
'injectedMaterial_product', 'injectedMaterialCost','percentageRecycledMaterial', 'maxDepth', 'maxWallThickness','productVolume', 'materozzaVolume', 'nAnniProduzione', 'nProdottiAnno',
 'materialDensity', 'tolerance', 'surfaceFinishing', 'cycleTime',
'machineCycleTime',
'maintenanceCost', 'productionCost','transportCost', 'mouldTotalCost',
'injectedMaterial_materozza', 'injectionMouldingProcess','memtiEngineValue', 'steelPrice', 'runnersType', 'mouldMaterialName',
'machineName', 'EUUSMacchina', 'CNMacchina', 'gateDiameter', 'setupTime', 'warmupTime', 'deliveryVolume', 'deliveryPeriod','mouldDesignCostDisplay']

output_variables= ['human health - total', 
                   'ecosystem quality - total',
                    'resources - total', 
                      'Cost']

# %%
# Minimal VPBO for threshold and hidden size over four targets

import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from typing import Callable, Optional, Tuple, List, Dict

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
from scipy.optimize import minimize, Bounds
from joblib import Parallel, delayed
import dcor
import torch
import time

# ------------------------------
# data
# ------------------------------
# expects df_small already in memory, else load csv
try:
    _df = df_small.copy()
except NameError:
    _df = pd.read_csv("df_encoded.csv")

selected_features = [
    'surfaceProcessingLocationCavity','hotRunner','hotRunnerCost',
    'manufacturingCost','mouldValidationCost','designTime',
    'hourlyDesignCost','removedChassis','weightChassisProcessed',
    'surfaceProcessingLocationChassis','removedCavity','numberOfCavities',
    'weightCavityProcessed','weightMould','totalTransportationPercentage',
    'percentageAircraft','percentageLorry','percentageTrain','percentageShip',
    'totalDistance','injectedMaterial_product','injectedMaterialCost',
    'percentageRecycledMaterial','maxDepth','maxWallThickness',
    'productVolume','materozzaVolume','nAnniProduzione','nProdottiAnno',
    'materialDensity','tolerance','surfaceFinishing','cycleTime',
    'machineCycleTime','maintenanceCost','productionCost',
    'injectedMaterial_materozza','injectionMouldingProcess','memtiEngineValue',
    'steelPrice','runnersType','mouldMaterialName','machineName',
    'EUUSMacchina','CNMacchina','gateDiameter','setupTime','warmupTime',
    'deliveryVolume','deliveryPeriod','mouldDesignCostDisplay','mouldTotalCost'
]

output_variables = [
    'human health - total',
    'ecosystem quality - total',
    'resources - total',
    'Cost'
]

X_raw = _df[selected_features].values
Y_raw = _df[output_variables].values

sx = MinMaxScaler()
sy = MinMaxScaler()
X = sx.fit_transform(X_raw)
Y = sy.fit_transform(Y_raw)

n_targets = Y.shape[1]

# ------------------------------
# utilities
# ------------------------------

# ------------------------------
# evaluator
# ------------------------------
from src import mlp_eval_mean, BO

# %% [markdown]
# ## Using Mean MRE across target variable
# dim = 2
# trial = 1
# split_num= 4

# %%
# ------------------------------
# run
# ------------------------------
dim = 2
bounds = Bounds(lb=np.zeros(dim), ub=np.ones(dim))
kernel = C(1.0, (1e-3, 1e3)) * RBF(length_scale=np.ones(dim))
bo = BO(distmod=mlp_eval_mean,
        args=(X, Y),
        dist_ref={'distrefmod': None},
        ref_args=(),
        dim=dim,
        bounds=bounds,
        kernel=kernel,
        exp_w=0.5,
        ub=np.ones(dim),
        lb=np.zeros(dim))

lim_init = np.array([0.5, 0.5])
bo.optimizer_vpbo(trials=1, split_num=4, lim_init=lim_init, f_cores=1, af_cores=1, ref_cores=1)
np.random.seed(0)

best_idx = np.argmin(np.mean(bo.y_vp, axis=1))
best_thr = float(bo.x_vp[best_idx, 0])
best_hidden = int(bo.x_vp[best_idx, 1] * 190 + 10)

print("Best threshold:", round(best_thr, 3))
print("Best hidden size:", best_hidden)
print("Best per target errors:", bo.y_vp[best_idx])
print("Dataset shapes:", bo.x_vp.shape, bo.y_vp.shape)
# Out:
# [Eval] thr=0.818, hidden=146, k=5, MRE=0.508807
# [Eval] thr=0.818, hidden=146, k=5, MRE=1.143605
# [Eval] thr=0.818, hidden=146, k=5, MRE=0.654131
# [Eval] thr=0.818, hidden=146, k=5, MRE=0.026227
#
# [Eval] thr=0.545, hidden=40, k=5, MRE=0.521032
# [Eval] thr=0.545, hidden=40, k=5, MRE=1.274861
# [Eval] thr=0.545, hidden=40, k=5, MRE=0.801591
# [Eval] thr=0.545, hidden=40, k=5, MRE=0.018244
#
# [Eval] thr=0.675, hidden=110, k=5, MRE=0.602012
# [Eval] thr=0.675, hidden=110, k=5, MRE=0.940310
# [Eval] thr=0.675, hidden=110, k=5, MRE=0.509103
# [Eval] thr=0.675, hidden=110, k=5, MRE=0.023702
#
# [Eval] thr=0.161, hidden=92, k=26, MRE=0.219415
# [Eval] thr=0.161, hidden=92, k=31, MRE=0.451148
# [Eval] thr=0.161, hidden=92, k=26, MRE=0.498013
# [Eval] thr=0.161, hidden=92, k=6, MRE=0.010394
#
# [Eval] thr=0.500, hidden=105, k=5, MRE=0.547458
# [Eval] thr=0.500, hidden=105, k=5, MRE=1.076845
# [Eval] thr=0.500, hidden=105, k=5, MRE=0.665808
# [Eval] thr=0.500, hidden=105, k=5, MRE=0.015263
#
# [Eval] thr=0.145, hidden=116, k=27, MRE=0.198802
# [Eval] thr=0.145, hidden=116, k=31, MRE=0.397775
# [Eval] thr=0.145, hidden=116, k=27, MRE=0.620464
# [Eval] thr=0.145, hidden=116, k=9, MRE=0.008109
#
# [Eval] thr=0.178, hidden=22, k=24, MRE=0.796989
# [Eval] thr=0.178, hidden=22, k=29, MRE=0.092645
# [Eval] thr=0.178, hidden=22, k=20, MRE=0.319276
# [Eval] thr=0.178, hidden=22, k=5, MRE=0.018790
#
# [Eval] thr=0.178, hidden=88, k=24, MRE=0.193671
# [Eval] thr=0.178, hidden=88, k=29, MRE=0.115408
# [Eval] thr=0.178, hidden=88, k=20, MRE=0.463361
# [Eval] thr=0.178, hidden=88, k=5, MRE=0.025691
#
# [Eval] thr=0.178, hidden=121, k=24, MRE=0.183798
# [Eval] thr=0.178, hidden=121, k=29, MRE=0.524332
# [Eval] thr=0.178, hidden=121, k=20, MRE=0.667967
# [Eval] thr=0.178, hidden=121, k=5, MRE=0.018221
#
# [Eval] thr=0.170, hidden=87, k=26, MRE=0.385836
# [Eval] thr=0.170, hidden=87, k=29, MRE=0.136635
# [Eval] thr=0.170, hidden=87, k=26, MRE=1.214254
# [Eval] thr=0.170, hidden=87, k=5, MRE=0.038223
#
# Best threshold: 0.178
# Best hidden size: 88
# Best per target errors: [0.19953277]
# Dataset shapes: (10, 2) (10, 1)

# %% [markdown]
# ## Using Indivual Splits with separate objective functions

# %% [markdown]
# ### trials=1 splits=4 dim=2

# %%
# main.py
import os
import logging
from pathlib import Path
import numpy as np
from scipy.optimize import Bounds
import src as vpbo
from src import distmod_4


dim = 2
splits = 4
f_cores= 4

# make log folder
LOG_DIR = Path(f"log_folder_splits_{splits}_f_cores_{f_cores}")
LOG_DIR.mkdir(parents=True, exist_ok=True)
LOG_FILE = LOG_DIR / "run.log"

# root logging: console and file
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(name)s %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    handlers=[logging.StreamHandler(), logging.FileHandler(LOG_FILE, encoding="utf-8")],
)

# route module logs to root
mod_logger = logging.getLogger(vpbo.__name__)  # 'src'
mod_logger.handlers.clear()
mod_logger.propagate = True
mod_logger.setLevel(logging.DEBUG)  # optional

bounds = Bounds(lb=np.zeros(dim), ub=np.ones(dim))
kernel = C(1.0, (1e-3, 1e3)) * RBF(length_scale=np.ones(dim))

bo = BO(distmod=distmod_4,
        args=(X, Y),
        dist_ref={'distrefmod': None},
        ref_args=(),
        dim=dim,
        bounds=bounds,
        kernel=kernel,
        exp_w=0.5)

lim_init = np.array([0.5, 0.5])
bo.optimizer_vpbo(trials=1, split_num=splits, lim_init=lim_init, f_cores=f_cores, af_cores=4, ref_cores=1)

# best per split
for s, name in enumerate(output_variables):
    idx = int(np.argmin(bo.y_vp[:, s]))
    thr = float(bo.x_vp[idx, 0])
    hid = int(np.clip(bo.x_vp[idx, 1], 0.0, 1.0) * 190 + 10)
    err = float(bo.y_vp[idx, s])
    print(name, "thr", round(thr, 3), "hidden", hid, "MRE", err)
# Out:
# 2025-09-04 10:12:29 INFO src optimizer_vpbo start trials=1 splits=4 dim=2
# 2025-09-04 10:12:29 DEBUG src random seed for splits created shape=(4, 2)
# 2025-09-04 10:12:42 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 10:12:42 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 10:12:42 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 10:12:43 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 10:14:01 INFO src [Eval] thr=0.335, hidden=15, k=7, MRE=0.496454
# 2025-09-04 10:14:01 INFO src [Eval] thr=0.335, hidden=15, k=8, MRE=0.266854
# 2025-09-04 10:14:01 INFO src [Eval] thr=0.335, hidden=15, k=7, MRE=0.852024
# 2025-09-04 10:14:01 INFO src [Eval] thr=0.335, hidden=15, k=5, MRE=0.018056
# 2025-09-04 10:14:01 INFO src
# 2025-09-04 10:14:01 INFO src distmod_4 done in 78.088s
# 2025-09-04 10:14:01 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 10:14:14 INFO src [Eval] thr=0.281, hidden=35, k=8, MRE=0.537378
# 2025-09-04 10:14:14 INFO src [Eval] thr=0.281, hidden=35, k=11, MRE=0.352008
# 2025-09-04 10:14:14 INFO src [Eval] thr=0.281, hidden=35, k=7, MRE=0.612199
# 2025-09-04 10:14:14 INFO src [Eval] thr=0.281, hidden=35, k=5, MRE=0.031561
# 2025-09-04 10:14:14 INFO src
# 2025-09-04 10:14:14 INFO src distmod_4 done in 91.475s
# 2025-09-04 10:14:25 INFO src [Eval] thr=0.882, hidden=111, k=5, MRE=0.455657
# 2025-09-04 10:14:25 INFO src [Eval] thr=0.882, hidden=111, k=5, MRE=0.840170
# 2025-09-04 10:14:25 INFO src [Eval] thr=0.882, hidden=111, k=5, MRE=0.618958
# 2025-09-04 10:14:25 INFO src [Eval] thr=0.882, hidden=111, k=5, MRE=0.012012
# 2025-09-04 10:14:25 INFO src
# 2025-09-04 10:14:25 INFO src distmod_4 done in 102.915s
# 2025-09-04 10:14:28 INFO src [Eval] thr=0.270, hidden=130, k=8, MRE=0.441407
# 2025-09-04 10:14:28 INFO src [Eval] thr=0.270, hidden=130, k=12, MRE=0.234209
# 2025-09-04 10:14:28 INFO src [Eval] thr=0.270, hidden=130, k=8, MRE=0.713607
# 2025-09-04 10:14:28 INFO src [Eval] thr=0.270, hidden=130, k=5, MRE=0.014299
# 2025-09-04 10:14:28 INFO src
# 2025-09-04 10:14:28 INFO src distmod_4 done in 105.443s
# 2025-09-04 10:15:28 INFO src [Eval] thr=0.500, hidden=105, k=5, MRE=0.496314
# 2025-09-04 10:15:28 INFO src [Eval] thr=0.500, hidden=105, k=5, MRE=0.821062
# 2025-09-04 10:15:28 INFO src [Eval] thr=0.500, hidden=105, k=5, MRE=1.136222
# 2025-09-04 10:15:28 INFO src [Eval] thr=0.500, hidden=105, k=5, MRE=0.020341
# 2025-09-04 10:15:28 INFO src
# 2025-09-04 10:15:28 INFO src distmod_4 done in 86.677s
# 2025-09-04 10:15:28 INFO src initial eval done n=5
# 2025-09-04 10:15:28 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 10:15:28 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 10:15:28 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 10:15:28 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 10:15:28 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 10:15:28 INFO src GP models initialized count=4
# 2025-09-04 10:15:28 DEBUG src restarts per split=8
# 2025-09-04 10:15:29 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 10:15:29 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 10:15:29 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 10:15:29 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 10:17:20 INFO src [Eval] thr=0.490, hidden=99, k=5, MRE=0.555214
# 2025-09-04 10:17:20 INFO src [Eval] thr=0.490, hidden=99, k=5, MRE=1.137586
# 2025-09-04 10:17:20 INFO src [Eval] thr=0.490, hidden=99, k=5, MRE=0.516807
# 2025-09-04 10:17:20 INFO src [Eval] thr=0.490, hidden=99, k=5, MRE=0.016229
# 2025-09-04 10:17:20 INFO src
# 2025-09-04 10:17:20 INFO src distmod_4 done in 111.841s
# 2025-09-04 10:17:20 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 10:17:26 INFO src [Eval] thr=0.676, hidden=130, k=5, MRE=0.799125
# 2025-09-04 10:17:26 INFO src [Eval] thr=0.676, hidden=130, k=5, MRE=1.206259
# 2025-09-04 10:17:26 INFO src [Eval] thr=0.676, hidden=130, k=5, MRE=0.503579
# 2025-09-04 10:17:26 INFO src [Eval] thr=0.676, hidden=130, k=5, MRE=0.014299
# 2025-09-04 10:17:26 INFO src
# 2025-09-04 10:17:26 INFO src distmod_4 done in 117.464s
# 2025-09-04 10:17:26 INFO src [Eval] thr=0.218, hidden=163, k=12, MRE=0.448857
# 2025-09-04 10:17:26 INFO src [Eval] thr=0.218, hidden=163, k=25, MRE=0.256688
# 2025-09-04 10:17:26 INFO src [Eval] thr=0.218, hidden=163, k=12, MRE=0.574210
# 2025-09-04 10:17:26 INFO src [Eval] thr=0.218, hidden=163, k=5, MRE=0.029296
# 2025-09-04 10:17:26 INFO src
# 2025-09-04 10:17:26 INFO src distmod_4 done in 117.754s
# 2025-09-04 10:17:29 INFO src [Eval] thr=0.651, hidden=149, k=5, MRE=0.495980
# 2025-09-04 10:17:29 INFO src [Eval] thr=0.651, hidden=149, k=5, MRE=0.843924
# 2025-09-04 10:17:29 INFO src [Eval] thr=0.651, hidden=149, k=5, MRE=0.761596
# 2025-09-04 10:17:29 INFO src [Eval] thr=0.651, hidden=149, k=5, MRE=0.044378
# 2025-09-04 10:17:29 INFO src
# 2025-09-04 10:17:29 INFO src distmod_4 done in 119.977s
# 2025-09-04 10:18:37 INFO src [Eval] thr=0.509, hidden=135, k=5, MRE=0.640401
# 2025-09-04 10:18:37 INFO src [Eval] thr=0.509, hidden=135, k=5, MRE=0.785782
# 2025-09-04 10:18:37 INFO src [Eval] thr=0.509, hidden=135, k=5, MRE=0.608777
# 2025-09-04 10:18:37 INFO src [Eval] thr=0.509, hidden=135, k=5, MRE=0.022672
# 2025-09-04 10:18:37 INFO src
# 2025-09-04 10:18:37 INFO src distmod_4 done in 76.335s
# 2025-09-04 10:18:37 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 10:18:37 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 10:18:37 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 10:18:37 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 10:18:37 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 10:18:37 INFO src iter=1 evals_total=10 best_current=[0.441407,0.234209,0.503579,0.012012] dt_iter=189.214s dt_total=368.211s
# 2025-09-04 10:18:37 INFO src optimizer_vpbo done total_evals=10 total_time=368.213s
# human health - total thr 0.27 hidden 130 MRE 0.44140679545960204
# ecosystem quality - total thr 0.27 hidden 130 MRE 0.23420884512771484
# resources - total thr 0.676 hidden 130 MRE 0.5035794748678518
# Cost thr 0.882 hidden 111 MRE 0.012012393583630088

# %% [markdown]
# ### trials=10, splits=4, dim=2

# %%
# main.py
import os
import logging
from pathlib import Path
import numpy as np
from scipy.optimize import Bounds
import src as vpbo
from src import distmod_4


dim = 2
splits = 4
f_cores= 4

# make log folder
LOG_DIR = Path(f"log_folder_splits_{splits}_f_cores_{f_cores}")
LOG_DIR.mkdir(parents=True, exist_ok=True)
LOG_FILE = LOG_DIR / "run.log"

# root logging: console and file
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(name)s %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    handlers=[logging.StreamHandler(), logging.FileHandler(LOG_FILE, encoding="utf-8")],
)

# route module logs to root
mod_logger = logging.getLogger(vpbo.__name__)  # 'src'
mod_logger.handlers.clear()
mod_logger.propagate = True
mod_logger.setLevel(logging.DEBUG)  # optional

bounds = Bounds(lb=np.zeros(dim), ub=np.ones(dim))
kernel = C(1.0, (1e-3, 1e3)) * RBF(length_scale=np.ones(dim))

bo = BO(distmod=distmod_4,
        args=(X, Y),
        dist_ref={'distrefmod': None},
        ref_args=(),
        dim=dim,
        bounds=bounds,
        kernel=kernel,
        exp_w=0.5)

lim_init = np.array([0.5, 0.5])
bo.optimizer_vpbo(trials=10, split_num=splits, lim_init=lim_init, f_cores=f_cores, af_cores=4, ref_cores=1)

# best per split
for s, name in enumerate(output_variables):
    idx = int(np.argmin(bo.y_vp[:, s]))
    thr = float(bo.x_vp[idx, 0])
    hid = int(np.clip(bo.x_vp[idx, 1], 0.0, 1.0) * 190 + 10)
    err = float(bo.y_vp[idx, s])
    print(name, "thr", round(thr, 3), "hidden", hid, "MRE", err)
# Out:
# 2025-09-04 13:31:30 INFO src optimizer_vpbo start trials=10 splits=4 dim=2
# 2025-09-04 13:31:30 DEBUG src random seed for splits created shape=(4, 2)
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f06a9e02ac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f59a2932ac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f1612c62ac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fd501f02ac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f45abcbeac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fa8b6002ac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f9e67c22ac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7ff02b456ac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f298926eac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7ff9c58caac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fcf76e36ac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fee98daaac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# 2025-09-04 13:31:45 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:31:45 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:31:45 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:31:45 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:33:07 INFO src [Eval] thr=0.340, hidden=26, k=6, MRE=0.630709
# 2025-09-04 13:33:07 INFO src [Eval] thr=0.340, hidden=26, k=8, MRE=0.306286
# 2025-09-04 13:33:07 INFO src [Eval] thr=0.340, hidden=26, k=6, MRE=0.704887
# 2025-09-04 13:33:07 INFO src [Eval] thr=0.340, hidden=26, k=5, MRE=0.013570
# 2025-09-04 13:33:07 INFO src
# 2025-09-04 13:33:07 INFO src distmod_4 done in 81.605s
# 2025-09-04 13:33:07 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:33:24 INFO src [Eval] thr=0.769, hidden=80, k=5, MRE=0.799108
# 2025-09-04 13:33:24 INFO src [Eval] thr=0.769, hidden=80, k=5, MRE=1.396751
# 2025-09-04 13:33:24 INFO src [Eval] thr=0.769, hidden=80, k=5, MRE=0.711352
# 2025-09-04 13:33:24 INFO src [Eval] thr=0.769, hidden=80, k=5, MRE=0.035168
# 2025-09-04 13:33:24 INFO src
# 2025-09-04 13:33:24 INFO src distmod_4 done in 99.153s
# 2025-09-04 13:33:36 INFO src [Eval] thr=0.622, hidden=170, k=5, MRE=0.475056
# 2025-09-04 13:33:36 INFO src [Eval] thr=0.622, hidden=170, k=5, MRE=1.086974
# 2025-09-04 13:33:36 INFO src [Eval] thr=0.622, hidden=170, k=5, MRE=0.538399
# 2025-09-04 13:33:36 INFO src [Eval] thr=0.622, hidden=170, k=5, MRE=0.029349
# 2025-09-04 13:33:36 INFO src
# 2025-09-04 13:33:36 INFO src distmod_4 done in 110.655s
# 2025-09-04 13:33:44 INFO src [Eval] thr=0.057, hidden=185, k=35, MRE=0.161373
# 2025-09-04 13:33:44 INFO src [Eval] thr=0.057, hidden=185, k=36, MRE=0.317993
# 2025-09-04 13:33:44 INFO src [Eval] thr=0.057, hidden=185, k=35, MRE=0.396387
# 2025-09-04 13:33:44 INFO src [Eval] thr=0.057, hidden=185, k=34, MRE=0.003108
# 2025-09-04 13:33:44 INFO src
# 2025-09-04 13:33:44 INFO src distmod_4 done in 118.459s
# 2025-09-04 13:34:43 INFO src [Eval] thr=0.500, hidden=105, k=5, MRE=0.496314
# 2025-09-04 13:34:43 INFO src [Eval] thr=0.500, hidden=105, k=5, MRE=0.821062
# 2025-09-04 13:34:43 INFO src [Eval] thr=0.500, hidden=105, k=5, MRE=1.136222
# 2025-09-04 13:34:43 INFO src [Eval] thr=0.500, hidden=105, k=5, MRE=0.020341
# 2025-09-04 13:34:43 INFO src
# 2025-09-04 13:34:43 INFO src distmod_4 done in 95.657s
# 2025-09-04 13:34:43 INFO src initial eval done n=5
# 2025-09-04 13:34:43 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:34:43 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:34:43 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:34:43 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:34:43 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:34:43 INFO src GP models initialized count=4
# 2025-09-04 13:34:43 DEBUG src restarts per split=8
# 2025-09-04 13:34:44 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:34:44 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:34:44 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:34:44 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:36:08 INFO src [Eval] thr=0.146, hidden=10, k=27, MRE=0.187047
# 2025-09-04 13:36:08 INFO src [Eval] thr=0.146, hidden=10, k=31, MRE=0.106465
# 2025-09-04 13:36:08 INFO src [Eval] thr=0.146, hidden=10, k=27, MRE=0.375140
# 2025-09-04 13:36:08 INFO src [Eval] thr=0.146, hidden=10, k=9, MRE=0.009503
# 2025-09-04 13:36:08 INFO src
# 2025-09-04 13:36:08 INFO src distmod_4 done in 84.352s
# 2025-09-04 13:36:08 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:36:26 INFO src [Eval] thr=0.698, hidden=76, k=5, MRE=0.575413
# 2025-09-04 13:36:26 INFO src [Eval] thr=0.698, hidden=76, k=5, MRE=1.329246
# 2025-09-04 13:36:26 INFO src [Eval] thr=0.698, hidden=76, k=5, MRE=1.046628
# 2025-09-04 13:36:26 INFO src [Eval] thr=0.698, hidden=76, k=5, MRE=0.020726
# 2025-09-04 13:36:26 INFO src
# 2025-09-04 13:36:26 INFO src distmod_4 done in 101.783s
# 2025-09-04 13:36:26 INFO src [Eval] thr=0.000, hidden=30, k=52, MRE=0.419998
# 2025-09-04 13:36:26 INFO src [Eval] thr=0.000, hidden=30, k=52, MRE=0.103343
# 2025-09-04 13:36:26 INFO src [Eval] thr=0.000, hidden=30, k=52, MRE=0.452576
# 2025-09-04 13:36:26 INFO src [Eval] thr=0.000, hidden=30, k=52, MRE=0.004305
# 2025-09-04 13:36:26 INFO src
# 2025-09-04 13:36:26 INFO src distmod_4 done in 102.151s
# 2025-09-04 13:36:37 INFO src [Eval] thr=0.019, hidden=200, k=36, MRE=0.150095
# 2025-09-04 13:36:37 INFO src [Eval] thr=0.019, hidden=200, k=36, MRE=0.206253
# 2025-09-04 13:36:37 INFO src [Eval] thr=0.019, hidden=200, k=36, MRE=0.344990
# 2025-09-04 13:36:37 INFO src [Eval] thr=0.019, hidden=200, k=36, MRE=0.002815
# 2025-09-04 13:36:37 INFO src
# 2025-09-04 13:36:37 INFO src distmod_4 done in 112.524s
# 2025-09-04 13:37:34 INFO src [Eval] thr=0.216, hidden=79, k=12, MRE=0.330946
# 2025-09-04 13:37:34 INFO src [Eval] thr=0.216, hidden=79, k=25, MRE=0.506831
# 2025-09-04 13:37:34 INFO src [Eval] thr=0.216, hidden=79, k=12, MRE=0.234735
# 2025-09-04 13:37:34 INFO src [Eval] thr=0.216, hidden=79, k=5, MRE=0.048482
# 2025-09-04 13:37:34 INFO src
# 2025-09-04 13:37:34 INFO src distmod_4 done in 85.172s
# 2025-09-04 13:37:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:37:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:37:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:37:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:37:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:37:34 INFO src iter=1 evals_total=10 best_current=[0.150095,0.103343,0.234735,0.002815] dt_iter=170.606s dt_total=363.580s
# 2025-09-04 13:37:35 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:37:35 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:37:35 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:37:35 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:38:58 INFO src [Eval] thr=0.408, hidden=30, k=6, MRE=0.622754
# 2025-09-04 13:38:58 INFO src [Eval] thr=0.408, hidden=30, k=6, MRE=1.114245
# 2025-09-04 13:38:58 INFO src [Eval] thr=0.408, hidden=30, k=6, MRE=1.030264
# 2025-09-04 13:38:58 INFO src [Eval] thr=0.408, hidden=30, k=5, MRE=0.017328
# 2025-09-04 13:38:58 INFO src
# 2025-09-04 13:38:58 INFO src distmod_4 done in 83.607s
# 2025-09-04 13:38:58 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:39:04 INFO src [Eval] thr=0.765, hidden=32, k=5, MRE=0.623544
# 2025-09-04 13:39:04 INFO src [Eval] thr=0.765, hidden=32, k=5, MRE=1.294385
# 2025-09-04 13:39:04 INFO src [Eval] thr=0.765, hidden=32, k=5, MRE=0.668057
# 2025-09-04 13:39:04 INFO src [Eval] thr=0.765, hidden=32, k=5, MRE=0.025595
# 2025-09-04 13:39:04 INFO src
# 2025-09-04 13:39:04 INFO src distmod_4 done in 89.691s
# 2025-09-04 13:39:18 INFO src [Eval] thr=0.380, hidden=130, k=6, MRE=0.475420
# 2025-09-04 13:39:18 INFO src [Eval] thr=0.380, hidden=130, k=6, MRE=0.999378
# 2025-09-04 13:39:18 INFO src [Eval] thr=0.380, hidden=130, k=6, MRE=1.450705
# 2025-09-04 13:39:18 INFO src [Eval] thr=0.380, hidden=130, k=5, MRE=0.014299
# 2025-09-04 13:39:18 INFO src
# 2025-09-04 13:39:18 INFO src distmod_4 done in 103.317s
# 2025-09-04 13:39:19 INFO src [Eval] thr=0.796, hidden=189, k=5, MRE=0.549915
# 2025-09-04 13:39:19 INFO src [Eval] thr=0.796, hidden=189, k=5, MRE=0.917577
# 2025-09-04 13:39:19 INFO src [Eval] thr=0.796, hidden=189, k=5, MRE=0.576384
# 2025-09-04 13:39:19 INFO src [Eval] thr=0.796, hidden=189, k=5, MRE=0.010033
# 2025-09-04 13:39:19 INFO src
# 2025-09-04 13:39:19 INFO src distmod_4 done in 104.352s
# 2025-09-04 13:40:19 INFO src [Eval] thr=0.587, hidden=95, k=5, MRE=0.778847
# 2025-09-04 13:40:19 INFO src [Eval] thr=0.587, hidden=95, k=5, MRE=1.203025
# 2025-09-04 13:40:19 INFO src [Eval] thr=0.587, hidden=95, k=5, MRE=0.913990
# 2025-09-04 13:40:19 INFO src [Eval] thr=0.587, hidden=95, k=5, MRE=0.021000
# 2025-09-04 13:40:19 INFO src
# 2025-09-04 13:40:19 INFO src distmod_4 done in 81.149s
# 2025-09-04 13:40:20 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:40:20 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:40:20 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:40:20 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:40:20 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:40:20 INFO src iter=2 evals_total=15 best_current=[0.150095,0.103343,0.234735,0.002815] dt_iter=165.851s dt_total=529.432s
# 2025-09-04 13:40:21 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:40:21 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:40:21 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:40:21 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:42:07 INFO src [Eval] thr=0.197, hidden=106, k=16, MRE=0.219871
# 2025-09-04 13:42:07 INFO src [Eval] thr=0.197, hidden=106, k=28, MRE=0.468104
# 2025-09-04 13:42:07 INFO src [Eval] thr=0.197, hidden=106, k=16, MRE=0.481239
# 2025-09-04 13:42:07 INFO src [Eval] thr=0.197, hidden=106, k=5, MRE=0.028843
# 2025-09-04 13:42:07 INFO src
# 2025-09-04 13:42:07 INFO src distmod_4 done in 106.699s
# 2025-09-04 13:42:07 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:42:13 INFO src [Eval] thr=0.141, hidden=121, k=28, MRE=0.585803
# 2025-09-04 13:42:13 INFO src [Eval] thr=0.141, hidden=121, k=32, MRE=0.108812
# 2025-09-04 13:42:13 INFO src [Eval] thr=0.141, hidden=121, k=27, MRE=0.592261
# 2025-09-04 13:42:13 INFO src [Eval] thr=0.141, hidden=121, k=11, MRE=0.009283
# 2025-09-04 13:42:13 INFO src
# 2025-09-04 13:42:13 INFO src distmod_4 done in 112.209s
# 2025-09-04 13:42:13 INFO src [Eval] thr=0.665, hidden=162, k=5, MRE=0.565032
# 2025-09-04 13:42:13 INFO src [Eval] thr=0.665, hidden=162, k=5, MRE=1.042093
# 2025-09-04 13:42:13 INFO src [Eval] thr=0.665, hidden=162, k=5, MRE=0.549130
# 2025-09-04 13:42:13 INFO src [Eval] thr=0.665, hidden=162, k=5, MRE=0.012568
# 2025-09-04 13:42:13 INFO src
# 2025-09-04 13:42:13 INFO src distmod_4 done in 112.678s
# 2025-09-04 13:42:22 INFO src [Eval] thr=0.022, hidden=165, k=36, MRE=0.259155
# 2025-09-04 13:42:22 INFO src [Eval] thr=0.022, hidden=165, k=36, MRE=0.062449
# 2025-09-04 13:42:22 INFO src [Eval] thr=0.022, hidden=165, k=36, MRE=0.593059
# 2025-09-04 13:42:22 INFO src [Eval] thr=0.022, hidden=165, k=36, MRE=0.003594
# 2025-09-04 13:42:22 INFO src
# 2025-09-04 13:42:22 INFO src distmod_4 done in 121.707s
# 2025-09-04 13:43:22 INFO src [Eval] thr=0.256, hidden=138, k=9, MRE=0.466818
# 2025-09-04 13:43:22 INFO src [Eval] thr=0.256, hidden=138, k=13, MRE=0.459733
# 2025-09-04 13:43:22 INFO src [Eval] thr=0.256, hidden=138, k=9, MRE=0.607399
# 2025-09-04 13:43:22 INFO src [Eval] thr=0.256, hidden=138, k=5, MRE=0.018862
# 2025-09-04 13:43:22 INFO src
# 2025-09-04 13:43:22 INFO src distmod_4 done in 74.696s
# 2025-09-04 13:43:22 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:43:22 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:43:22 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:43:22 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:43:22 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:43:22 INFO src iter=3 evals_total=20 best_current=[0.150095,0.062449,0.234735,0.002815] dt_iter=182.608s dt_total=712.041s
# 2025-09-04 13:43:23 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:43:23 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:43:23 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:43:23 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:44:49 INFO src [Eval] thr=0.878, hidden=39, k=5, MRE=0.414582
# 2025-09-04 13:44:49 INFO src [Eval] thr=0.878, hidden=39, k=5, MRE=1.131426
# 2025-09-04 13:44:49 INFO src [Eval] thr=0.878, hidden=39, k=5, MRE=0.607038
# 2025-09-04 13:44:49 INFO src [Eval] thr=0.878, hidden=39, k=5, MRE=0.017455
# 2025-09-04 13:44:49 INFO src
# 2025-09-04 13:44:49 INFO src distmod_4 done in 85.796s
# 2025-09-04 13:44:49 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:44:49 INFO src [Eval] thr=0.137, hidden=14, k=28, MRE=0.464007
# 2025-09-04 13:44:49 INFO src [Eval] thr=0.137, hidden=14, k=32, MRE=0.115512
# 2025-09-04 13:44:49 INFO src [Eval] thr=0.137, hidden=14, k=28, MRE=0.265809
# 2025-09-04 13:44:49 INFO src [Eval] thr=0.137, hidden=14, k=12, MRE=0.005303
# 2025-09-04 13:44:49 INFO src
# 2025-09-04 13:44:49 INFO src distmod_4 done in 86.227s
# 2025-09-04 13:45:00 INFO src [Eval] thr=0.894, hidden=78, k=5, MRE=0.491583
# 2025-09-04 13:45:00 INFO src [Eval] thr=0.894, hidden=78, k=5, MRE=1.099908
# 2025-09-04 13:45:00 INFO src [Eval] thr=0.894, hidden=78, k=5, MRE=0.501030
# 2025-09-04 13:45:00 INFO src [Eval] thr=0.894, hidden=78, k=5, MRE=0.030151
# 2025-09-04 13:45:00 INFO src
# 2025-09-04 13:45:00 INFO src distmod_4 done in 96.264s
# 2025-09-04 13:45:03 INFO src [Eval] thr=0.360, hidden=81, k=6, MRE=0.542189
# 2025-09-04 13:45:03 INFO src [Eval] thr=0.360, hidden=81, k=6, MRE=0.900319
# 2025-09-04 13:45:03 INFO src [Eval] thr=0.360, hidden=81, k=6, MRE=1.551234
# 2025-09-04 13:45:03 INFO src [Eval] thr=0.360, hidden=81, k=5, MRE=0.022989
# 2025-09-04 13:45:03 INFO src
# 2025-09-04 13:45:03 INFO src distmod_4 done in 99.630s
# 2025-09-04 13:46:02 INFO src [Eval] thr=0.567, hidden=53, k=5, MRE=0.560384
# 2025-09-04 13:46:02 INFO src [Eval] thr=0.567, hidden=53, k=5, MRE=1.154378
# 2025-09-04 13:46:02 INFO src [Eval] thr=0.567, hidden=53, k=5, MRE=0.722979
# 2025-09-04 13:46:02 INFO src [Eval] thr=0.567, hidden=53, k=5, MRE=0.029905
# 2025-09-04 13:46:02 INFO src
# 2025-09-04 13:46:02 INFO src distmod_4 done in 73.302s
# 2025-09-04 13:46:02 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:46:02 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:46:02 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:46:02 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:46:02 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:46:03 INFO src iter=4 evals_total=25 best_current=[0.150095,0.062449,0.234735,0.002815] dt_iter=160.487s dt_total=872.529s
# 2025-09-04 13:46:04 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:46:04 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:46:04 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:46:04 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:47:24 INFO src [Eval] thr=0.842, hidden=20, k=5, MRE=0.539714
# 2025-09-04 13:47:24 INFO src [Eval] thr=0.842, hidden=20, k=5, MRE=1.255989
# 2025-09-04 13:47:24 INFO src [Eval] thr=0.842, hidden=20, k=5, MRE=0.711849
# 2025-09-04 13:47:24 INFO src [Eval] thr=0.842, hidden=20, k=5, MRE=0.015606
# 2025-09-04 13:47:24 INFO src
# 2025-09-04 13:47:24 INFO src distmod_4 done in 79.903s
# 2025-09-04 13:47:24 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:47:36 INFO src [Eval] thr=0.961, hidden=53, k=5, MRE=0.560384
# 2025-09-04 13:47:36 INFO src [Eval] thr=0.961, hidden=53, k=5, MRE=1.154378
# 2025-09-04 13:47:36 INFO src [Eval] thr=0.961, hidden=53, k=5, MRE=0.722979
# 2025-09-04 13:47:36 INFO src [Eval] thr=0.961, hidden=53, k=5, MRE=0.029905
# 2025-09-04 13:47:36 INFO src
# 2025-09-04 13:47:36 INFO src distmod_4 done in 91.893s
# 2025-09-04 13:47:38 INFO src [Eval] thr=0.825, hidden=55, k=5, MRE=0.882769
# 2025-09-04 13:47:38 INFO src [Eval] thr=0.825, hidden=55, k=5, MRE=1.215012
# 2025-09-04 13:47:38 INFO src [Eval] thr=0.825, hidden=55, k=5, MRE=0.581775
# 2025-09-04 13:47:38 INFO src [Eval] thr=0.825, hidden=55, k=5, MRE=0.021304
# 2025-09-04 13:47:38 INFO src
# 2025-09-04 13:47:38 INFO src distmod_4 done in 94.324s
# 2025-09-04 13:47:39 INFO src [Eval] thr=0.759, hidden=113, k=5, MRE=0.396622
# 2025-09-04 13:47:39 INFO src [Eval] thr=0.759, hidden=113, k=5, MRE=1.725495
# 2025-09-04 13:47:39 INFO src [Eval] thr=0.759, hidden=113, k=5, MRE=0.621361
# 2025-09-04 13:47:39 INFO src [Eval] thr=0.759, hidden=113, k=5, MRE=0.027570
# 2025-09-04 13:47:39 INFO src
# 2025-09-04 13:47:39 INFO src distmod_4 done in 95.611s
# 2025-09-04 13:48:50 INFO src [Eval] thr=0.847, hidden=60, k=5, MRE=0.585503
# 2025-09-04 13:48:50 INFO src [Eval] thr=0.847, hidden=60, k=5, MRE=1.811637
# 2025-09-04 13:48:50 INFO src [Eval] thr=0.847, hidden=60, k=5, MRE=0.602987
# 2025-09-04 13:48:50 INFO src [Eval] thr=0.847, hidden=60, k=5, MRE=0.028307
# 2025-09-04 13:48:50 INFO src
# 2025-09-04 13:48:50 INFO src distmod_4 done in 86.507s
# 2025-09-04 13:48:50 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:48:50 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:48:50 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:48:50 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:48:50 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:48:51 INFO src iter=5 evals_total=30 best_current=[0.150095,0.062449,0.234735,0.002815] dt_iter=167.795s dt_total=1040.325s
# 2025-09-04 13:48:52 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:48:52 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:48:52 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:48:52 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:50:13 INFO src [Eval] thr=0.483, hidden=32, k=5, MRE=0.623544
# 2025-09-04 13:50:13 INFO src [Eval] thr=0.483, hidden=32, k=5, MRE=1.294385
# 2025-09-04 13:50:13 INFO src [Eval] thr=0.483, hidden=32, k=5, MRE=0.668057
# 2025-09-04 13:50:13 INFO src [Eval] thr=0.483, hidden=32, k=5, MRE=0.025595
# 2025-09-04 13:50:13 INFO src
# 2025-09-04 13:50:13 INFO src distmod_4 done in 81.833s
# 2025-09-04 13:50:13 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:50:37 INFO src [Eval] thr=0.941, hidden=121, k=5, MRE=0.555572
# 2025-09-04 13:50:37 INFO src [Eval] thr=0.941, hidden=121, k=5, MRE=2.077098
# 2025-09-04 13:50:37 INFO src [Eval] thr=0.941, hidden=121, k=5, MRE=0.651491
# 2025-09-04 13:50:37 INFO src [Eval] thr=0.941, hidden=121, k=5, MRE=0.017955
# 2025-09-04 13:50:37 INFO src
# 2025-09-04 13:50:37 INFO src distmod_4 done in 105.944s
# 2025-09-04 13:50:41 INFO src [Eval] thr=0.855, hidden=125, k=5, MRE=0.490438
# 2025-09-04 13:50:41 INFO src [Eval] thr=0.855, hidden=125, k=5, MRE=1.415422
# 2025-09-04 13:50:41 INFO src [Eval] thr=0.855, hidden=125, k=5, MRE=0.706955
# 2025-09-04 13:50:41 INFO src [Eval] thr=0.855, hidden=125, k=5, MRE=0.018556
# 2025-09-04 13:50:41 INFO src
# 2025-09-04 13:50:41 INFO src distmod_4 done in 109.063s
# 2025-09-04 13:50:45 INFO src [Eval] thr=0.304, hidden=139, k=7, MRE=0.556823
# 2025-09-04 13:50:45 INFO src [Eval] thr=0.304, hidden=139, k=10, MRE=0.319786
# 2025-09-04 13:50:45 INFO src [Eval] thr=0.304, hidden=139, k=7, MRE=0.602701
# 2025-09-04 13:50:45 INFO src [Eval] thr=0.304, hidden=139, k=5, MRE=0.027265
# 2025-09-04 13:50:45 INFO src
# 2025-09-04 13:50:45 INFO src distmod_4 done in 113.482s
# 2025-09-04 13:51:40 INFO src [Eval] thr=0.646, hidden=104, k=5, MRE=0.467355
# 2025-09-04 13:51:40 INFO src [Eval] thr=0.646, hidden=104, k=5, MRE=1.358203
# 2025-09-04 13:51:40 INFO src [Eval] thr=0.646, hidden=104, k=5, MRE=0.610378
# 2025-09-04 13:51:40 INFO src [Eval] thr=0.646, hidden=104, k=5, MRE=0.039132
# 2025-09-04 13:51:40 INFO src
# 2025-09-04 13:51:40 INFO src distmod_4 done in 86.590s
# 2025-09-04 13:51:40 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:51:40 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:51:40 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:51:40 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:51:40 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:51:41 INFO src iter=6 evals_total=35 best_current=[0.150095,0.062449,0.234735,0.002815] dt_iter=170.309s dt_total=1210.636s
# 2025-09-04 13:51:42 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:51:42 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:51:42 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:51:42 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:53:11 INFO src [Eval] thr=0.326, hidden=10, k=7, MRE=0.571930
# 2025-09-04 13:53:11 INFO src [Eval] thr=0.326, hidden=10, k=9, MRE=0.262985
# 2025-09-04 13:53:11 INFO src [Eval] thr=0.326, hidden=10, k=7, MRE=0.961062
# 2025-09-04 13:53:11 INFO src [Eval] thr=0.326, hidden=10, k=5, MRE=0.027094
# 2025-09-04 13:53:11 INFO src
# 2025-09-04 13:53:11 INFO src distmod_4 done in 89.325s
# 2025-09-04 13:53:11 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:53:25 INFO src [Eval] thr=0.598, hidden=116, k=5, MRE=0.572755
# 2025-09-04 13:53:25 INFO src [Eval] thr=0.598, hidden=116, k=5, MRE=1.031518
# 2025-09-04 13:53:25 INFO src [Eval] thr=0.598, hidden=116, k=5, MRE=0.644533
# 2025-09-04 13:53:25 INFO src [Eval] thr=0.598, hidden=116, k=5, MRE=0.038830
# 2025-09-04 13:53:25 INFO src
# 2025-09-04 13:53:25 INFO src distmod_4 done in 103.126s
# 2025-09-04 13:53:36 INFO src [Eval] thr=0.846, hidden=199, k=5, MRE=0.809687
# 2025-09-04 13:53:36 INFO src [Eval] thr=0.846, hidden=199, k=5, MRE=0.798095
# 2025-09-04 13:53:36 INFO src [Eval] thr=0.846, hidden=199, k=5, MRE=0.990389
# 2025-09-04 13:53:36 INFO src [Eval] thr=0.846, hidden=199, k=5, MRE=0.019196
# 2025-09-04 13:53:36 INFO src
# 2025-09-04 13:53:36 INFO src distmod_4 done in 114.021s
# 2025-09-04 13:53:39 INFO src [Eval] thr=0.528, hidden=189, k=5, MRE=0.549915
# 2025-09-04 13:53:39 INFO src [Eval] thr=0.528, hidden=189, k=5, MRE=0.917577
# 2025-09-04 13:53:39 INFO src [Eval] thr=0.528, hidden=189, k=5, MRE=0.576384
# 2025-09-04 13:53:39 INFO src [Eval] thr=0.528, hidden=189, k=5, MRE=0.010033
# 2025-09-04 13:53:39 INFO src
# 2025-09-04 13:53:39 INFO src distmod_4 done in 117.273s
# 2025-09-04 13:54:46 INFO src [Eval] thr=0.574, hidden=129, k=5, MRE=0.524308
# 2025-09-04 13:54:46 INFO src [Eval] thr=0.574, hidden=129, k=5, MRE=1.290516
# 2025-09-04 13:54:46 INFO src [Eval] thr=0.574, hidden=129, k=5, MRE=0.572509
# 2025-09-04 13:54:46 INFO src [Eval] thr=0.574, hidden=129, k=5, MRE=0.014313
# 2025-09-04 13:54:46 INFO src
# 2025-09-04 13:54:46 INFO src distmod_4 done in 94.455s
# 2025-09-04 13:54:46 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:54:46 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:54:46 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:54:46 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:54:46 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:54:46 INFO src iter=7 evals_total=40 best_current=[0.150095,0.062449,0.234735,0.002815] dt_iter=185.412s dt_total=1396.050s
# 2025-09-04 13:54:47 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:54:47 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:54:47 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:54:47 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:56:02 INFO src [Eval] thr=0.938, hidden=10, k=5, MRE=0.553957
# 2025-09-04 13:56:02 INFO src [Eval] thr=0.938, hidden=10, k=5, MRE=0.965418
# 2025-09-04 13:56:02 INFO src [Eval] thr=0.938, hidden=10, k=5, MRE=0.586343
# 2025-09-04 13:56:02 INFO src [Eval] thr=0.938, hidden=10, k=5, MRE=0.027094
# 2025-09-04 13:56:02 INFO src
# 2025-09-04 13:56:02 INFO src distmod_4 done in 74.942s
# 2025-09-04 13:56:02 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:56:42 INFO src [Eval] thr=0.191, hidden=119, k=17, MRE=0.330458
# 2025-09-04 13:56:42 INFO src [Eval] thr=0.191, hidden=119, k=28, MRE=0.262875
# 2025-09-04 13:56:42 INFO src [Eval] thr=0.191, hidden=119, k=17, MRE=0.329577
# 2025-09-04 13:56:42 INFO src [Eval] thr=0.191, hidden=119, k=5, MRE=0.024087
# 2025-09-04 13:56:42 INFO src
# 2025-09-04 13:56:42 INFO src distmod_4 done in 114.944s
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f40d09deac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# 2025-09-04 13:56:44 INFO src [Eval] thr=0.020, hidden=125, k=36, MRE=0.328027
# 2025-09-04 13:56:44 INFO src [Eval] thr=0.020, hidden=125, k=36, MRE=0.086097
# 2025-09-04 13:56:44 INFO src [Eval] thr=0.020, hidden=125, k=36, MRE=0.294507
# 2025-09-04 13:56:44 INFO src [Eval] thr=0.020, hidden=125, k=36, MRE=0.005673
# 2025-09-04 13:56:44 INFO src
# 2025-09-04 13:56:44 INFO src distmod_4 done in 116.369s
# 2025-09-04 13:56:46 INFO src [Eval] thr=0.410, hidden=177, k=6, MRE=0.586606
# 2025-09-04 13:56:46 INFO src [Eval] thr=0.410, hidden=177, k=6, MRE=1.293352
# 2025-09-04 13:56:46 INFO src [Eval] thr=0.410, hidden=177, k=6, MRE=0.866563
# 2025-09-04 13:56:46 INFO src [Eval] thr=0.410, hidden=177, k=5, MRE=0.012728
# 2025-09-04 13:56:46 INFO src
# 2025-09-04 13:56:46 INFO src distmod_4 done in 118.302s
# 2025-09-04 13:57:45 INFO src [Eval] thr=0.390, hidden=108, k=6, MRE=0.505728
# 2025-09-04 13:57:45 INFO src [Eval] thr=0.390, hidden=108, k=6, MRE=1.235298
# 2025-09-04 13:57:45 INFO src [Eval] thr=0.390, hidden=108, k=6, MRE=0.529351
# 2025-09-04 13:57:45 INFO src [Eval] thr=0.390, hidden=108, k=5, MRE=0.028477
# 2025-09-04 13:57:45 INFO src
# 2025-09-04 13:57:45 INFO src distmod_4 done in 102.879s
# 2025-09-04 13:57:45 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:57:45 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:57:45 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:57:45 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:57:45 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 13:57:46 INFO src iter=8 evals_total=45 best_current=[0.150095,0.062449,0.234735,0.002815] dt_iter=179.702s dt_total=1575.813s
# 2025-09-04 13:58:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:58:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:58:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:58:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:59:32 INFO src [Eval] thr=0.694, hidden=57, k=5, MRE=0.513410
# 2025-09-04 13:59:32 INFO src [Eval] thr=0.694, hidden=57, k=5, MRE=0.865775
# 2025-09-04 13:59:32 INFO src [Eval] thr=0.694, hidden=57, k=5, MRE=0.951510
# 2025-09-04 13:59:32 INFO src [Eval] thr=0.694, hidden=57, k=5, MRE=0.018719
# 2025-09-04 13:59:32 INFO src
# 2025-09-04 13:59:32 INFO src distmod_4 done in 91.600s
# 2025-09-04 13:59:32 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 13:59:32 INFO src [Eval] thr=0.562, hidden=57, k=5, MRE=0.513410
# 2025-09-04 13:59:32 INFO src [Eval] thr=0.562, hidden=57, k=5, MRE=0.865775
# 2025-09-04 13:59:32 INFO src [Eval] thr=0.562, hidden=57, k=5, MRE=0.951510
# 2025-09-04 13:59:32 INFO src [Eval] thr=0.562, hidden=57, k=5, MRE=0.018719
# 2025-09-04 13:59:32 INFO src
# 2025-09-04 13:59:32 INFO src distmod_4 done in 91.692s
# 2025-09-04 13:59:50 INFO src [Eval] thr=0.946, hidden=164, k=5, MRE=0.487977
# 2025-09-04 13:59:50 INFO src [Eval] thr=0.946, hidden=164, k=5, MRE=1.054829
# 2025-09-04 13:59:50 INFO src [Eval] thr=0.946, hidden=164, k=5, MRE=0.529192
# 2025-09-04 13:59:50 INFO src [Eval] thr=0.946, hidden=164, k=5, MRE=0.021084
# 2025-09-04 13:59:50 INFO src
# 2025-09-04 13:59:50 INFO src distmod_4 done in 109.032s
# 2025-09-04 13:59:56 INFO src [Eval] thr=0.027, hidden=161, k=36, MRE=0.147520
# 2025-09-04 13:59:56 INFO src [Eval] thr=0.027, hidden=161, k=36, MRE=0.284912
# 2025-09-04 13:59:56 INFO src [Eval] thr=0.027, hidden=161, k=36, MRE=0.618334
# 2025-09-04 13:59:56 INFO src [Eval] thr=0.027, hidden=161, k=36, MRE=0.003058
# 2025-09-04 13:59:56 INFO src
# 2025-09-04 13:59:56 INFO src distmod_4 done in 115.714s
# 2025-09-04 14:00:58 INFO src [Eval] thr=0.557, hidden=110, k=5, MRE=0.587494
# 2025-09-04 14:00:58 INFO src [Eval] thr=0.557, hidden=110, k=5, MRE=1.390447
# 2025-09-04 14:00:58 INFO src [Eval] thr=0.557, hidden=110, k=5, MRE=0.533744
# 2025-09-04 14:00:58 INFO src [Eval] thr=0.557, hidden=110, k=5, MRE=0.013755
# 2025-09-04 14:00:58 INFO src
# 2025-09-04 14:00:58 INFO src distmod_4 done in 85.866s
# 2025-09-04 14:00:58 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:00:58 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:00:58 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:00:58 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:00:58 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:00:59 INFO src iter=9 evals_total=50 best_current=[0.14752 ,0.062449,0.234735,0.002815] dt_iter=192.610s dt_total=1768.426s
# 2025-09-04 14:01:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:01:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:01:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:01:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:02:26 INFO src [Eval] thr=0.779, hidden=44, k=5, MRE=0.557186
# 2025-09-04 14:02:26 INFO src [Eval] thr=0.779, hidden=44, k=5, MRE=0.894778
# 2025-09-04 14:02:26 INFO src [Eval] thr=0.779, hidden=44, k=5, MRE=0.740197
# 2025-09-04 14:02:26 INFO src [Eval] thr=0.779, hidden=44, k=5, MRE=0.014275
# 2025-09-04 14:02:26 INFO src
# 2025-09-04 14:02:26 INFO src distmod_4 done in 86.760s
# 2025-09-04 14:02:26 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:02:46 INFO src [Eval] thr=0.100, hidden=52, k=30, MRE=0.283504
# 2025-09-04 14:02:46 INFO src [Eval] thr=0.100, hidden=52, k=34, MRE=0.079923
# 2025-09-04 14:02:46 INFO src [Eval] thr=0.100, hidden=52, k=30, MRE=0.398227
# 2025-09-04 14:02:46 INFO src [Eval] thr=0.100, hidden=52, k=23, MRE=0.010457
# 2025-09-04 14:02:46 INFO src
# 2025-09-04 14:02:46 INFO src distmod_4 done in 106.270s
# Exception ignored in: <function ResourceTracker.__del__ at 0x7ff589ddaac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# 2025-09-04 14:02:55 INFO src [Eval] thr=0.601, hidden=88, k=5, MRE=0.502506
# 2025-09-04 14:02:55 INFO src [Eval] thr=0.601, hidden=88, k=5, MRE=1.207398
# 2025-09-04 14:02:55 INFO src [Eval] thr=0.601, hidden=88, k=5, MRE=0.609840
# 2025-09-04 14:02:55 INFO src [Eval] thr=0.601, hidden=88, k=5, MRE=0.013333
# 2025-09-04 14:02:55 INFO src
# 2025-09-04 14:02:55 INFO src distmod_4 done in 115.601s
# 2025-09-04 14:02:56 INFO src [Eval] thr=0.573, hidden=147, k=5, MRE=0.585733
# 2025-09-04 14:02:56 INFO src [Eval] thr=0.573, hidden=147, k=5, MRE=1.047698
# 2025-09-04 14:02:56 INFO src [Eval] thr=0.573, hidden=147, k=5, MRE=1.244594
# 2025-09-04 14:02:56 INFO src [Eval] thr=0.573, hidden=147, k=5, MRE=0.013059
# 2025-09-04 14:02:56 INFO src
# 2025-09-04 14:02:56 INFO src distmod_4 done in 116.157s
# 2025-09-04 14:03:59 INFO src [Eval] thr=0.513, hidden=83, k=5, MRE=0.530172
# 2025-09-04 14:03:59 INFO src [Eval] thr=0.513, hidden=83, k=5, MRE=1.322909
# 2025-09-04 14:03:59 INFO src [Eval] thr=0.513, hidden=83, k=5, MRE=0.587689
# 2025-09-04 14:03:59 INFO src [Eval] thr=0.513, hidden=83, k=5, MRE=0.020185
# 2025-09-04 14:03:59 INFO src
# 2025-09-04 14:03:59 INFO src distmod_4 done in 92.782s
# 2025-09-04 14:03:59 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:03:59 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:03:59 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:03:59 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:03:59 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:04:00 INFO src iter=10 evals_total=55 best_current=[0.14752 ,0.062449,0.234735,0.002815] dt_iter=181.404s dt_total=1949.831s
# 2025-09-04 14:04:00 INFO src optimizer_vpbo done total_evals=55 total_time=1949.833s
# human health - total thr 0.027 hidden 161 MRE 0.1475196326336562
# ecosystem quality - total thr 0.022 hidden 165 MRE 0.06244881118700339
# resources - total thr 0.216 hidden 79 MRE 0.23473544777000524
# Cost thr 0.019 hidden 200 MRE 0.00281482823759533
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f97df05eac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fc29505aac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes

# %% [markdown]
# ### trials=20, splits=4, dim=2

# %%
# main.py
import os
import logging
from pathlib import Path
import numpy as np
from scipy.optimize import Bounds
import src as vpbo
from src import distmod_4


dim = 2
splits = 4
f_cores= 4
trials= 20

# make log folder
LOG_DIR = Path(f"log_folder_{trials}_splits_{splits}_f_cores_{f_cores}")
LOG_DIR.mkdir(parents=True, exist_ok=True)
LOG_FILE = LOG_DIR / "run.log"

# root logging: console and file
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(name)s %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    handlers=[logging.StreamHandler(), logging.FileHandler(LOG_FILE, encoding="utf-8")],
)

# route module logs to root
mod_logger = logging.getLogger(vpbo.__name__)  # 'src'
mod_logger.handlers.clear()
mod_logger.propagate = True
mod_logger.setLevel(logging.DEBUG)  # optional

bounds = Bounds(lb=np.zeros(dim), ub=np.ones(dim))
kernel = C(1.0, (1e-3, 1e3)) * RBF(length_scale=np.ones(dim))

bo = BO(distmod=distmod_4,
        args=(X, Y),
        dist_ref={'distrefmod': None},
        ref_args=(),
        dim=dim,
        bounds=bounds,
        kernel=kernel,
        exp_w=0.5)

lim_init = np.array([0.5, 0.5])
bo.optimizer_vpbo(trials=trials, split_num=splits, lim_init=lim_init, f_cores=f_cores, af_cores=4, ref_cores=1)

# best per split
for s, name in enumerate(output_variables):
    idx = int(np.argmin(bo.y_vp[:, s]))
    thr = float(bo.x_vp[idx, 0])
    hid = int(np.clip(bo.x_vp[idx, 1], 0.0, 1.0) * 190 + 10)
    err = float(bo.y_vp[idx, s])
    print(name, "thr", round(thr, 3), "hidden", hid, "MRE", err)
# Out:
# 2025-09-04 14:09:15 INFO src optimizer_vpbo start trials=20 splits=4 dim=2
# 2025-09-04 14:09:15 DEBUG src random seed for splits created shape=(4, 2)
# 2025-09-04 14:09:29 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:09:29 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:09:29 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:09:29 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:11:04 INFO src [Eval] thr=0.719, hidden=65, k=5, MRE=0.499337
# 2025-09-04 14:11:04 INFO src [Eval] thr=0.719, hidden=65, k=5, MRE=1.059270
# 2025-09-04 14:11:04 INFO src [Eval] thr=0.719, hidden=65, k=5, MRE=0.507453
# 2025-09-04 14:11:04 INFO src [Eval] thr=0.719, hidden=65, k=5, MRE=0.009077
# 2025-09-04 14:11:04 INFO src
# 2025-09-04 14:11:04 INFO src distmod_4 done in 95.132s
# 2025-09-04 14:11:05 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:11:13 INFO src [Eval] thr=0.740, hidden=115, k=5, MRE=0.587271
# 2025-09-04 14:11:13 INFO src [Eval] thr=0.740, hidden=115, k=5, MRE=1.545505
# 2025-09-04 14:11:13 INFO src [Eval] thr=0.740, hidden=115, k=5, MRE=0.553665
# 2025-09-04 14:11:13 INFO src [Eval] thr=0.740, hidden=115, k=5, MRE=0.026834
# 2025-09-04 14:11:13 INFO src
# 2025-09-04 14:11:13 INFO src distmod_4 done in 103.759s
# 2025-09-04 14:11:16 INFO src [Eval] thr=0.578, hidden=132, k=5, MRE=0.652031
# 2025-09-04 14:11:16 INFO src [Eval] thr=0.578, hidden=132, k=5, MRE=1.763528
# 2025-09-04 14:11:16 INFO src [Eval] thr=0.578, hidden=132, k=5, MRE=0.664403
# 2025-09-04 14:11:16 INFO src [Eval] thr=0.578, hidden=132, k=5, MRE=0.023791
# 2025-09-04 14:11:16 INFO src
# 2025-09-04 14:11:16 INFO src distmod_4 done in 107.001s
# 2025-09-04 14:11:16 INFO src [Eval] thr=0.589, hidden=119, k=5, MRE=0.692923
# 2025-09-04 14:11:16 INFO src [Eval] thr=0.589, hidden=119, k=5, MRE=1.349782
# 2025-09-04 14:11:16 INFO src [Eval] thr=0.589, hidden=119, k=5, MRE=0.578697
# 2025-09-04 14:11:16 INFO src [Eval] thr=0.589, hidden=119, k=5, MRE=0.024087
# 2025-09-04 14:11:16 INFO src
# 2025-09-04 14:11:16 INFO src distmod_4 done in 107.010s
# 2025-09-04 14:12:29 INFO src [Eval] thr=0.500, hidden=105, k=5, MRE=0.496314
# 2025-09-04 14:12:29 INFO src [Eval] thr=0.500, hidden=105, k=5, MRE=0.821062
# 2025-09-04 14:12:29 INFO src [Eval] thr=0.500, hidden=105, k=5, MRE=1.136222
# 2025-09-04 14:12:29 INFO src [Eval] thr=0.500, hidden=105, k=5, MRE=0.020341
# 2025-09-04 14:12:29 INFO src
# 2025-09-04 14:12:29 INFO src distmod_4 done in 84.747s
# 2025-09-04 14:12:29 INFO src initial eval done n=5
# 2025-09-04 14:12:29 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:12:29 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:12:29 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:12:29 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:12:29 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:12:30 INFO src GP models initialized count=4
# 2025-09-04 14:12:30 DEBUG src restarts per split=8
# 2025-09-04 14:12:30 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:12:30 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:12:30 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:12:30 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:14:02 INFO src [Eval] thr=0.147, hidden=14, k=27, MRE=0.223889
# 2025-09-04 14:14:02 INFO src [Eval] thr=0.147, hidden=14, k=31, MRE=0.104388
# 2025-09-04 14:14:02 INFO src [Eval] thr=0.147, hidden=14, k=27, MRE=0.345744
# 2025-09-04 14:14:02 INFO src [Eval] thr=0.147, hidden=14, k=8, MRE=0.017328
# 2025-09-04 14:14:02 INFO src
# 2025-09-04 14:14:02 INFO src distmod_4 done in 91.916s
# 2025-09-04 14:14:02 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:14:22 INFO src [Eval] thr=0.982, hidden=170, k=5, MRE=0.475056
# 2025-09-04 14:14:22 INFO src [Eval] thr=0.982, hidden=170, k=5, MRE=1.086974
# 2025-09-04 14:14:22 INFO src [Eval] thr=0.982, hidden=170, k=5, MRE=0.538399
# 2025-09-04 14:14:22 INFO src [Eval] thr=0.982, hidden=170, k=5, MRE=0.029349
# 2025-09-04 14:14:22 INFO src
# 2025-09-04 14:14:22 INFO src distmod_4 done in 111.916s
# 2025-09-04 14:14:24 INFO src [Eval] thr=0.612, hidden=140, k=5, MRE=0.501838
# 2025-09-04 14:14:24 INFO src [Eval] thr=0.612, hidden=140, k=5, MRE=0.835670
# 2025-09-04 14:14:24 INFO src [Eval] thr=0.612, hidden=140, k=5, MRE=0.516558
# 2025-09-04 14:14:24 INFO src [Eval] thr=0.612, hidden=140, k=5, MRE=0.014771
# 2025-09-04 14:14:24 INFO src
# 2025-09-04 14:14:24 INFO src distmod_4 done in 113.760s
# 2025-09-04 14:14:30 INFO src [Eval] thr=0.546, hidden=196, k=5, MRE=0.550427
# 2025-09-04 14:14:30 INFO src [Eval] thr=0.546, hidden=196, k=5, MRE=1.446357
# 2025-09-04 14:14:30 INFO src [Eval] thr=0.546, hidden=196, k=5, MRE=0.868404
# 2025-09-04 14:14:30 INFO src [Eval] thr=0.546, hidden=196, k=5, MRE=0.043322
# 2025-09-04 14:14:30 INFO src
# 2025-09-04 14:14:30 INFO src distmod_4 done in 119.189s
# 2025-09-04 14:15:36 INFO src [Eval] thr=0.572, hidden=130, k=5, MRE=0.799125
# 2025-09-04 14:15:36 INFO src [Eval] thr=0.572, hidden=130, k=5, MRE=1.206259
# 2025-09-04 14:15:36 INFO src [Eval] thr=0.572, hidden=130, k=5, MRE=0.503579
# 2025-09-04 14:15:36 INFO src [Eval] thr=0.572, hidden=130, k=5, MRE=0.014299
# 2025-09-04 14:15:36 INFO src
# 2025-09-04 14:15:36 INFO src distmod_4 done in 93.359s
# 2025-09-04 14:15:36 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:15:36 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:15:36 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:15:36 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:15:36 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:15:36 INFO src iter=1 evals_total=10 best_current=[0.223889,0.104388,0.345744,0.009077] dt_iter=186.336s dt_total=380.485s
# 2025-09-04 14:15:37 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:15:37 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:15:37 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:15:37 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:17:05 INFO src [Eval] thr=0.775, hidden=58, k=5, MRE=0.484870
# 2025-09-04 14:17:05 INFO src [Eval] thr=0.775, hidden=58, k=5, MRE=0.945602
# 2025-09-04 14:17:05 INFO src [Eval] thr=0.775, hidden=58, k=5, MRE=0.521462
# 2025-09-04 14:17:05 INFO src [Eval] thr=0.775, hidden=58, k=5, MRE=0.019102
# 2025-09-04 14:17:05 INFO src
# 2025-09-04 14:17:05 INFO src distmod_4 done in 87.893s
# 2025-09-04 14:17:05 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:17:17 INFO src [Eval] thr=0.618, hidden=80, k=5, MRE=0.799108
# 2025-09-04 14:17:17 INFO src [Eval] thr=0.618, hidden=80, k=5, MRE=1.396751
# 2025-09-04 14:17:17 INFO src [Eval] thr=0.618, hidden=80, k=5, MRE=0.711352
# 2025-09-04 14:17:17 INFO src [Eval] thr=0.618, hidden=80, k=5, MRE=0.035168
# 2025-09-04 14:17:17 INFO src
# 2025-09-04 14:17:17 INFO src distmod_4 done in 100.303s
# 2025-09-04 14:17:21 INFO src [Eval] thr=0.906, hidden=130, k=5, MRE=0.799125
# 2025-09-04 14:17:21 INFO src [Eval] thr=0.906, hidden=130, k=5, MRE=1.206259
# 2025-09-04 14:17:21 INFO src [Eval] thr=0.906, hidden=130, k=5, MRE=0.503579
# 2025-09-04 14:17:21 INFO src [Eval] thr=0.906, hidden=130, k=5, MRE=0.014299
# 2025-09-04 14:17:21 INFO src
# 2025-09-04 14:17:21 INFO src distmod_4 done in 104.327s
# 2025-09-04 14:17:30 INFO src [Eval] thr=0.091, hidden=131, k=31, MRE=0.233030
# 2025-09-04 14:17:30 INFO src [Eval] thr=0.091, hidden=131, k=35, MRE=0.075876
# 2025-09-04 14:17:30 INFO src [Eval] thr=0.091, hidden=131, k=30, MRE=0.278285
# 2025-09-04 14:17:30 INFO src [Eval] thr=0.091, hidden=131, k=26, MRE=0.008646
# 2025-09-04 14:17:30 INFO src
# 2025-09-04 14:17:30 INFO src distmod_4 done in 113.335s
# 2025-09-04 14:18:32 INFO src [Eval] thr=0.597, hidden=100, k=5, MRE=0.642450
# 2025-09-04 14:18:32 INFO src [Eval] thr=0.597, hidden=100, k=5, MRE=1.479535
# 2025-09-04 14:18:32 INFO src [Eval] thr=0.597, hidden=100, k=5, MRE=0.613270
# 2025-09-04 14:18:32 INFO src [Eval] thr=0.597, hidden=100, k=5, MRE=0.012956
# 2025-09-04 14:18:32 INFO src
# 2025-09-04 14:18:32 INFO src distmod_4 done in 87.154s
# 2025-09-04 14:18:32 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:18:32 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:18:32 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:18:32 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:18:32 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:18:32 INFO src iter=2 evals_total=15 best_current=[0.223889,0.075876,0.278285,0.008646] dt_iter=176.184s dt_total=556.670s
# 2025-09-04 14:18:33 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:18:33 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:18:33 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:18:33 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:19:57 INFO src [Eval] thr=0.987, hidden=28, k=5, MRE=0.456134
# 2025-09-04 14:19:57 INFO src [Eval] thr=0.987, hidden=28, k=5, MRE=1.067520
# 2025-09-04 14:19:57 INFO src [Eval] thr=0.987, hidden=28, k=5, MRE=0.636265
# 2025-09-04 14:19:57 INFO src [Eval] thr=0.987, hidden=28, k=5, MRE=0.022561
# 2025-09-04 14:19:57 INFO src
# 2025-09-04 14:19:57 INFO src distmod_4 done in 84.179s
# 2025-09-04 14:19:57 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:20:12 INFO src [Eval] thr=0.562, hidden=88, k=5, MRE=0.502506
# 2025-09-04 14:20:12 INFO src [Eval] thr=0.562, hidden=88, k=5, MRE=1.207398
# 2025-09-04 14:20:12 INFO src [Eval] thr=0.562, hidden=88, k=5, MRE=0.609840
# 2025-09-04 14:20:12 INFO src [Eval] thr=0.562, hidden=88, k=5, MRE=0.013333
# 2025-09-04 14:20:12 INFO src
# 2025-09-04 14:20:12 INFO src distmod_4 done in 99.479s
# 2025-09-04 14:20:13 INFO src [Eval] thr=0.862, hidden=110, k=5, MRE=0.587494
# 2025-09-04 14:20:13 INFO src [Eval] thr=0.862, hidden=110, k=5, MRE=1.390447
# 2025-09-04 14:20:13 INFO src [Eval] thr=0.862, hidden=110, k=5, MRE=0.533744
# 2025-09-04 14:20:13 INFO src [Eval] thr=0.862, hidden=110, k=5, MRE=0.013755
# 2025-09-04 14:20:13 INFO src
# 2025-09-04 14:20:13 INFO src distmod_4 done in 99.789s
# 2025-09-04 14:20:18 INFO src [Eval] thr=0.715, hidden=135, k=5, MRE=0.640401
# 2025-09-04 14:20:18 INFO src [Eval] thr=0.715, hidden=135, k=5, MRE=0.785782
# 2025-09-04 14:20:18 INFO src [Eval] thr=0.715, hidden=135, k=5, MRE=0.608777
# 2025-09-04 14:20:18 INFO src [Eval] thr=0.715, hidden=135, k=5, MRE=0.022672
# 2025-09-04 14:20:18 INFO src
# 2025-09-04 14:20:18 INFO src distmod_4 done in 105.508s
# 2025-09-04 14:21:23 INFO src [Eval] thr=0.782, hidden=90, k=5, MRE=0.448221
# 2025-09-04 14:21:23 INFO src [Eval] thr=0.782, hidden=90, k=5, MRE=1.159598
# 2025-09-04 14:21:23 INFO src [Eval] thr=0.782, hidden=90, k=5, MRE=0.633907
# 2025-09-04 14:21:23 INFO src [Eval] thr=0.782, hidden=90, k=5, MRE=0.012529
# 2025-09-04 14:21:23 INFO src
# 2025-09-04 14:21:23 INFO src distmod_4 done in 86.178s
# 2025-09-04 14:21:23 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:21:23 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:21:23 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:21:23 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:21:23 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:21:24 INFO src iter=3 evals_total=20 best_current=[0.223889,0.075876,0.278285,0.008646] dt_iter=171.501s dt_total=728.172s
# 2025-09-04 14:21:24 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:21:24 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:21:24 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:21:24 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:22:46 INFO src [Eval] thr=0.849, hidden=15, k=5, MRE=0.569602
# 2025-09-04 14:22:46 INFO src [Eval] thr=0.849, hidden=15, k=5, MRE=0.935504
# 2025-09-04 14:22:46 INFO src [Eval] thr=0.849, hidden=15, k=5, MRE=0.639193
# 2025-09-04 14:22:46 INFO src [Eval] thr=0.849, hidden=15, k=5, MRE=0.018056
# 2025-09-04 14:22:46 INFO src
# 2025-09-04 14:22:46 INFO src distmod_4 done in 81.569s
# 2025-09-04 14:22:46 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:23:06 INFO src [Eval] thr=0.445, hidden=124, k=5, MRE=0.632430
# 2025-09-04 14:23:06 INFO src [Eval] thr=0.445, hidden=124, k=5, MRE=1.189439
# 2025-09-04 14:23:06 INFO src [Eval] thr=0.445, hidden=124, k=5, MRE=0.540274
# 2025-09-04 14:23:06 INFO src [Eval] thr=0.445, hidden=124, k=5, MRE=0.018149
# 2025-09-04 14:23:06 INFO src
# 2025-09-04 14:23:06 INFO src distmod_4 done in 101.948s
# 2025-09-04 14:23:07 INFO src [Eval] thr=0.194, hidden=73, k=17, MRE=0.270222
# 2025-09-04 14:23:07 INFO src [Eval] thr=0.194, hidden=73, k=28, MRE=0.182805
# 2025-09-04 14:23:07 INFO src [Eval] thr=0.194, hidden=73, k=16, MRE=0.561512
# 2025-09-04 14:23:07 INFO src [Eval] thr=0.194, hidden=73, k=5, MRE=0.027830
# 2025-09-04 14:23:07 INFO src
# 2025-09-04 14:23:07 INFO src distmod_4 done in 102.783s
# 2025-09-04 14:23:20 INFO src [Eval] thr=0.084, hidden=172, k=34, MRE=0.175112
# 2025-09-04 14:23:20 INFO src [Eval] thr=0.084, hidden=172, k=36, MRE=0.081941
# 2025-09-04 14:23:20 INFO src [Eval] thr=0.084, hidden=172, k=30, MRE=0.252139
# 2025-09-04 14:23:20 INFO src [Eval] thr=0.084, hidden=172, k=29, MRE=0.004506
# 2025-09-04 14:23:20 INFO src
# 2025-09-04 14:23:20 INFO src distmod_4 done in 115.393s
# 2025-09-04 14:24:15 INFO src [Eval] thr=0.393, hidden=96, k=6, MRE=0.625366
# 2025-09-04 14:24:15 INFO src [Eval] thr=0.393, hidden=96, k=6, MRE=1.204748
# 2025-09-04 14:24:15 INFO src [Eval] thr=0.393, hidden=96, k=6, MRE=0.552351
# 2025-09-04 14:24:15 INFO src [Eval] thr=0.393, hidden=96, k=5, MRE=0.039538
# 2025-09-04 14:24:15 INFO src
# 2025-09-04 14:24:15 INFO src distmod_4 done in 89.051s
# 2025-09-04 14:24:15 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:24:15 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:24:15 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:24:15 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:24:15 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:24:16 INFO src iter=4 evals_total=25 best_current=[0.175112,0.075876,0.252139,0.004506] dt_iter=171.958s dt_total=900.132s
# 2025-09-04 14:24:16 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:24:16 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:24:16 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:24:16 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:25:49 INFO src [Eval] thr=0.614, hidden=64, k=5, MRE=0.492721
# 2025-09-04 14:25:49 INFO src [Eval] thr=0.614, hidden=64, k=5, MRE=1.250795
# 2025-09-04 14:25:49 INFO src [Eval] thr=0.614, hidden=64, k=5, MRE=1.068451
# 2025-09-04 14:25:49 INFO src [Eval] thr=0.614, hidden=64, k=5, MRE=0.020245
# 2025-09-04 14:25:49 INFO src
# 2025-09-04 14:25:49 INFO src distmod_4 done in 92.687s
# 2025-09-04 14:25:49 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:25:50 INFO src [Eval] thr=0.237, hidden=68, k=12, MRE=0.790778
# 2025-09-04 14:25:50 INFO src [Eval] thr=0.237, hidden=68, k=17, MRE=0.274449
# 2025-09-04 14:25:50 INFO src [Eval] thr=0.237, hidden=68, k=11, MRE=0.374304
# 2025-09-04 14:25:50 INFO src [Eval] thr=0.237, hidden=68, k=5, MRE=0.017434
# 2025-09-04 14:25:50 INFO src
# 2025-09-04 14:25:50 INFO src distmod_4 done in 93.476s
# 2025-09-04 14:25:59 INFO src [Eval] thr=0.483, hidden=146, k=5, MRE=0.708858
# 2025-09-04 14:25:59 INFO src [Eval] thr=0.483, hidden=146, k=5, MRE=1.286949
# 2025-09-04 14:25:59 INFO src [Eval] thr=0.483, hidden=146, k=5, MRE=0.660923
# 2025-09-04 14:25:59 INFO src [Eval] thr=0.483, hidden=146, k=5, MRE=0.013204
# 2025-09-04 14:25:59 INFO src
# 2025-09-04 14:25:59 INFO src distmod_4 done in 102.780s
# 2025-09-04 14:26:05 INFO src [Eval] thr=0.855, hidden=197, k=5, MRE=0.627232
# 2025-09-04 14:26:05 INFO src [Eval] thr=0.855, hidden=197, k=5, MRE=0.946754
# 2025-09-04 14:26:05 INFO src [Eval] thr=0.855, hidden=197, k=5, MRE=0.592388
# 2025-09-04 14:26:05 INFO src [Eval] thr=0.855, hidden=197, k=5, MRE=0.022179
# 2025-09-04 14:26:05 INFO src
# 2025-09-04 14:26:05 INFO src distmod_4 done in 108.325s
# 2025-09-04 14:27:12 INFO src [Eval] thr=0.547, hidden=119, k=5, MRE=0.692923
# 2025-09-04 14:27:12 INFO src [Eval] thr=0.547, hidden=119, k=5, MRE=1.349782
# 2025-09-04 14:27:12 INFO src [Eval] thr=0.547, hidden=119, k=5, MRE=0.578697
# 2025-09-04 14:27:12 INFO src [Eval] thr=0.547, hidden=119, k=5, MRE=0.024087
# 2025-09-04 14:27:12 INFO src
# 2025-09-04 14:27:12 INFO src distmod_4 done in 83.219s
# 2025-09-04 14:27:12 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:27:12 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:27:12 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:27:12 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:27:12 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:27:13 INFO src iter=5 evals_total=30 best_current=[0.175112,0.075876,0.252139,0.004506] dt_iter=177.207s dt_total=1077.342s
# 2025-09-04 14:27:14 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:27:14 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:27:14 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:27:14 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:28:36 INFO src [Eval] thr=0.862, hidden=29, k=5, MRE=0.512596
# 2025-09-04 14:28:36 INFO src [Eval] thr=0.862, hidden=29, k=5, MRE=0.943621
# 2025-09-04 14:28:36 INFO src [Eval] thr=0.862, hidden=29, k=5, MRE=0.810881
# 2025-09-04 14:28:36 INFO src [Eval] thr=0.862, hidden=29, k=5, MRE=0.023483
# 2025-09-04 14:28:36 INFO src
# 2025-09-04 14:28:36 INFO src distmod_4 done in 82.407s
# 2025-09-04 14:28:36 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:28:36 INFO src [Eval] thr=0.457, hidden=23, k=5, MRE=0.642880
# 2025-09-04 14:28:36 INFO src [Eval] thr=0.457, hidden=23, k=5, MRE=1.231521
# 2025-09-04 14:28:36 INFO src [Eval] thr=0.457, hidden=23, k=5, MRE=0.650268
# 2025-09-04 14:28:36 INFO src [Eval] thr=0.457, hidden=23, k=5, MRE=0.008356
# 2025-09-04 14:28:36 INFO src
# 2025-09-04 14:28:36 INFO src distmod_4 done in 82.718s
# 2025-09-04 14:28:53 INFO src [Eval] thr=0.437, hidden=92, k=5, MRE=0.567792
# 2025-09-04 14:28:53 INFO src [Eval] thr=0.437, hidden=92, k=5, MRE=0.991429
# 2025-09-04 14:28:53 INFO src [Eval] thr=0.437, hidden=92, k=5, MRE=0.541835
# 2025-09-04 14:28:53 INFO src [Eval] thr=0.437, hidden=92, k=5, MRE=0.022647
# 2025-09-04 14:28:53 INFO src
# 2025-09-04 14:28:53 INFO src distmod_4 done in 99.319s
# 2025-09-04 14:28:57 INFO src [Eval] thr=0.220, hidden=146, k=12, MRE=0.314770
# 2025-09-04 14:28:57 INFO src [Eval] thr=0.220, hidden=146, k=24, MRE=0.174175
# 2025-09-04 14:28:57 INFO src [Eval] thr=0.220, hidden=146, k=12, MRE=0.282222
# 2025-09-04 14:28:57 INFO src [Eval] thr=0.220, hidden=146, k=5, MRE=0.013204
# 2025-09-04 14:28:57 INFO src
# 2025-09-04 14:28:57 INFO src distmod_4 done in 103.003s
# 2025-09-04 14:29:58 INFO src [Eval] thr=0.494, hidden=73, k=5, MRE=0.501521
# 2025-09-04 14:29:58 INFO src [Eval] thr=0.494, hidden=73, k=5, MRE=0.864673
# 2025-09-04 14:29:58 INFO src [Eval] thr=0.494, hidden=73, k=5, MRE=0.648123
# 2025-09-04 14:29:58 INFO src [Eval] thr=0.494, hidden=73, k=5, MRE=0.027830
# 2025-09-04 14:29:58 INFO src
# 2025-09-04 14:29:58 INFO src distmod_4 done in 81.898s
# 2025-09-04 14:29:58 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:29:58 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:29:58 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:29:58 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:29:58 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:29:59 INFO src iter=6 evals_total=35 best_current=[0.175112,0.075876,0.252139,0.004506] dt_iter=166.110s dt_total=1243.453s
# 2025-09-04 14:30:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:30:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:30:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:30:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:31:25 INFO src [Eval] thr=0.961, hidden=39, k=5, MRE=0.414582
# 2025-09-04 14:31:25 INFO src [Eval] thr=0.961, hidden=39, k=5, MRE=1.131426
# 2025-09-04 14:31:25 INFO src [Eval] thr=0.961, hidden=39, k=5, MRE=0.607038
# 2025-09-04 14:31:25 INFO src [Eval] thr=0.961, hidden=39, k=5, MRE=0.017455
# 2025-09-04 14:31:25 INFO src
# 2025-09-04 14:31:25 INFO src distmod_4 done in 85.210s
# 2025-09-04 14:31:25 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:31:44 INFO src [Eval] thr=0.854, hidden=93, k=5, MRE=0.723694
# 2025-09-04 14:31:44 INFO src [Eval] thr=0.854, hidden=93, k=5, MRE=1.128644
# 2025-09-04 14:31:44 INFO src [Eval] thr=0.854, hidden=93, k=5, MRE=0.859881
# 2025-09-04 14:31:44 INFO src [Eval] thr=0.854, hidden=93, k=5, MRE=0.040405
# 2025-09-04 14:31:44 INFO src
# 2025-09-04 14:31:44 INFO src distmod_4 done in 104.290s
# 2025-09-04 14:31:45 INFO src [Eval] thr=0.923, hidden=103, k=5, MRE=0.555614
# 2025-09-04 14:31:45 INFO src [Eval] thr=0.923, hidden=103, k=5, MRE=0.848121
# 2025-09-04 14:31:45 INFO src [Eval] thr=0.923, hidden=103, k=5, MRE=0.567277
# 2025-09-04 14:31:45 INFO src [Eval] thr=0.923, hidden=103, k=5, MRE=0.031706
# 2025-09-04 14:31:45 INFO src
# 2025-09-04 14:31:45 INFO src distmod_4 done in 105.517s
# 2025-09-04 14:31:52 INFO src [Eval] thr=0.560, hidden=190, k=5, MRE=0.453838
# 2025-09-04 14:31:52 INFO src [Eval] thr=0.560, hidden=190, k=5, MRE=0.799480
# 2025-09-04 14:31:52 INFO src [Eval] thr=0.560, hidden=190, k=5, MRE=0.543882
# 2025-09-04 14:31:52 INFO src [Eval] thr=0.560, hidden=190, k=5, MRE=0.039586
# 2025-09-04 14:31:52 INFO src
# 2025-09-04 14:31:52 INFO src distmod_4 done in 111.761s
# 2025-09-04 14:32:50 INFO src [Eval] thr=0.825, hidden=106, k=5, MRE=0.459311
# 2025-09-04 14:32:50 INFO src [Eval] thr=0.825, hidden=106, k=5, MRE=1.457986
# 2025-09-04 14:32:50 INFO src [Eval] thr=0.825, hidden=106, k=5, MRE=0.671046
# 2025-09-04 14:32:50 INFO src [Eval] thr=0.825, hidden=106, k=5, MRE=0.028843
# 2025-09-04 14:32:50 INFO src
# 2025-09-04 14:32:50 INFO src distmod_4 done in 85.108s
# 2025-09-04 14:32:50 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:32:50 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:32:50 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:32:50 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:32:50 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:32:51 INFO src iter=7 evals_total=40 best_current=[0.175112,0.075876,0.252139,0.004506] dt_iter=171.894s dt_total=1415.349s
# 2025-09-04 14:32:52 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:32:52 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:32:52 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:32:52 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:34:10 INFO src [Eval] thr=0.978, hidden=13, k=5, MRE=0.513248
# 2025-09-04 14:34:10 INFO src [Eval] thr=0.978, hidden=13, k=5, MRE=1.285554
# 2025-09-04 14:34:10 INFO src [Eval] thr=0.978, hidden=13, k=5, MRE=0.988952
# 2025-09-04 14:34:10 INFO src [Eval] thr=0.978, hidden=13, k=5, MRE=0.033519
# 2025-09-04 14:34:10 INFO src
# 2025-09-04 14:34:10 INFO src distmod_4 done in 77.901s
# 2025-09-04 14:34:10 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:34:10 INFO src [Eval] thr=0.599, hidden=17, k=5, MRE=0.472934
# 2025-09-04 14:34:10 INFO src [Eval] thr=0.599, hidden=17, k=5, MRE=1.228072
# 2025-09-04 14:34:10 INFO src [Eval] thr=0.599, hidden=17, k=5, MRE=0.567393
# 2025-09-04 14:34:10 INFO src [Eval] thr=0.599, hidden=17, k=5, MRE=0.017440
# 2025-09-04 14:34:10 INFO src
# 2025-09-04 14:34:10 INFO src distmod_4 done in 78.202s
# 2025-09-04 14:34:15 INFO src [Eval] thr=0.007, hidden=14, k=36, MRE=0.568298
# 2025-09-04 14:34:15 INFO src [Eval] thr=0.007, hidden=14, k=36, MRE=0.314913
# 2025-09-04 14:34:15 INFO src [Eval] thr=0.007, hidden=14, k=36, MRE=0.175419
# 2025-09-04 14:34:15 INFO src [Eval] thr=0.007, hidden=14, k=36, MRE=0.000959
# 2025-09-04 14:34:15 INFO src
# 2025-09-04 14:34:15 INFO src distmod_4 done in 83.722s
# 2025-09-04 14:34:30 INFO src [Eval] thr=0.121, hidden=160, k=29, MRE=0.245487
# 2025-09-04 14:34:30 INFO src [Eval] thr=0.121, hidden=160, k=32, MRE=0.176186
# 2025-09-04 14:34:30 INFO src [Eval] thr=0.121, hidden=160, k=28, MRE=0.651797
# 2025-09-04 14:34:30 INFO src [Eval] thr=0.121, hidden=160, k=14, MRE=0.004950
# 2025-09-04 14:34:30 INFO src
# 2025-09-04 14:34:30 INFO src distmod_4 done in 97.922s
# 2025-09-04 14:35:31 INFO src [Eval] thr=0.426, hidden=51, k=6, MRE=0.578728
# 2025-09-04 14:35:31 INFO src [Eval] thr=0.426, hidden=51, k=6, MRE=1.144090
# 2025-09-04 14:35:31 INFO src [Eval] thr=0.426, hidden=51, k=6, MRE=0.582479
# 2025-09-04 14:35:31 INFO src [Eval] thr=0.426, hidden=51, k=5, MRE=0.019715
# 2025-09-04 14:35:31 INFO src
# 2025-09-04 14:35:31 INFO src distmod_4 done in 81.062s
# 2025-09-04 14:35:31 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:35:31 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:35:31 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:35:31 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:35:31 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:35:31 INFO src iter=8 evals_total=45 best_current=[0.175112,0.075876,0.175419,0.000959] dt_iter=160.688s dt_total=1576.039s
# 2025-09-04 14:35:32 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:35:32 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:35:32 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:35:32 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:37:18 INFO src [Eval] thr=0.948, hidden=148, k=5, MRE=0.467991
# 2025-09-04 14:37:18 INFO src [Eval] thr=0.948, hidden=148, k=5, MRE=1.164631
# 2025-09-04 14:37:18 INFO src [Eval] thr=0.948, hidden=148, k=5, MRE=0.919333
# 2025-09-04 14:37:18 INFO src [Eval] thr=0.948, hidden=148, k=5, MRE=0.028179
# 2025-09-04 14:37:18 INFO src
# 2025-09-04 14:37:18 INFO src distmod_4 done in 105.312s
# 2025-09-04 14:37:18 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:37:21 INFO src [Eval] thr=0.984, hidden=74, k=5, MRE=0.533034
# 2025-09-04 14:37:21 INFO src [Eval] thr=0.984, hidden=74, k=5, MRE=1.383639
# 2025-09-04 14:37:21 INFO src [Eval] thr=0.984, hidden=74, k=5, MRE=0.582521
# 2025-09-04 14:37:21 INFO src [Eval] thr=0.984, hidden=74, k=5, MRE=0.037973
# 2025-09-04 14:37:21 INFO src
# 2025-09-04 14:37:21 INFO src distmod_4 done in 108.433s
# 2025-09-04 14:37:24 INFO src [Eval] thr=0.286, hidden=47, k=7, MRE=0.521535
# 2025-09-04 14:37:24 INFO src [Eval] thr=0.286, hidden=47, k=10, MRE=0.286544
# 2025-09-04 14:37:24 INFO src [Eval] thr=0.286, hidden=47, k=7, MRE=0.520356
# 2025-09-04 14:37:24 INFO src [Eval] thr=0.286, hidden=47, k=5, MRE=0.010143
# 2025-09-04 14:37:24 INFO src
# 2025-09-04 14:37:24 INFO src distmod_4 done in 111.491s
# 2025-09-04 14:37:27 INFO src [Eval] thr=0.472, hidden=185, k=5, MRE=0.861322
# 2025-09-04 14:37:27 INFO src [Eval] thr=0.472, hidden=185, k=5, MRE=1.112236
# 2025-09-04 14:37:27 INFO src [Eval] thr=0.472, hidden=185, k=5, MRE=1.286846
# 2025-09-04 14:37:27 INFO src [Eval] thr=0.472, hidden=185, k=5, MRE=0.013274
# 2025-09-04 14:37:27 INFO src
# 2025-09-04 14:37:27 INFO src distmod_4 done in 114.400s
# 2025-09-04 14:38:36 INFO src [Eval] thr=0.673, hidden=114, k=5, MRE=0.518868
# 2025-09-04 14:38:36 INFO src [Eval] thr=0.673, hidden=114, k=5, MRE=1.242601
# 2025-09-04 14:38:36 INFO src [Eval] thr=0.673, hidden=114, k=5, MRE=0.664176
# 2025-09-04 14:38:36 INFO src [Eval] thr=0.673, hidden=114, k=5, MRE=0.017702
# 2025-09-04 14:38:36 INFO src
# 2025-09-04 14:38:36 INFO src distmod_4 done in 78.369s
# 2025-09-04 14:38:36 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:38:36 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:38:36 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:38:36 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:38:36 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:38:37 INFO src iter=9 evals_total=50 best_current=[0.175112,0.075876,0.175419,0.000959] dt_iter=185.412s dt_total=1761.452s
# 2025-09-04 14:38:38 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:38:38 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:38:38 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:38:38 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:40:00 INFO src [Eval] thr=0.762, hidden=11, k=5, MRE=0.475795
# 2025-09-04 14:40:00 INFO src [Eval] thr=0.762, hidden=11, k=5, MRE=1.165253
# 2025-09-04 14:40:00 INFO src [Eval] thr=0.762, hidden=11, k=5, MRE=0.620425
# 2025-09-04 14:40:00 INFO src [Eval] thr=0.762, hidden=11, k=5, MRE=0.018695
# 2025-09-04 14:40:00 INFO src
# 2025-09-04 14:40:00 INFO src distmod_4 done in 82.611s
# 2025-09-04 14:40:00 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:40:37 INFO src [Eval] thr=0.537, hidden=161, k=5, MRE=0.517731
# 2025-09-04 14:40:37 INFO src [Eval] thr=0.537, hidden=161, k=5, MRE=1.103327
# 2025-09-04 14:40:37 INFO src [Eval] thr=0.537, hidden=161, k=5, MRE=0.640836
# 2025-09-04 14:40:37 INFO src [Eval] thr=0.537, hidden=161, k=5, MRE=0.021988
# 2025-09-04 14:40:37 INFO src
# 2025-09-04 14:40:37 INFO src distmod_4 done in 119.338s
# 2025-09-04 14:40:38 INFO src [Eval] thr=0.468, hidden=129, k=5, MRE=0.524308
# 2025-09-04 14:40:38 INFO src [Eval] thr=0.468, hidden=129, k=5, MRE=1.290516
# 2025-09-04 14:40:38 INFO src [Eval] thr=0.468, hidden=129, k=5, MRE=0.572509
# 2025-09-04 14:40:38 INFO src [Eval] thr=0.468, hidden=129, k=5, MRE=0.014313
# 2025-09-04 14:40:38 INFO src
# 2025-09-04 14:40:38 INFO src distmod_4 done in 120.062s
# 2025-09-04 14:40:42 INFO src [Eval] thr=0.939, hidden=157, k=5, MRE=0.553320
# 2025-09-04 14:40:42 INFO src [Eval] thr=0.939, hidden=157, k=5, MRE=1.125792
# 2025-09-04 14:40:42 INFO src [Eval] thr=0.939, hidden=157, k=5, MRE=0.996715
# 2025-09-04 14:40:42 INFO src [Eval] thr=0.939, hidden=157, k=5, MRE=0.041027
# 2025-09-04 14:40:42 INFO src
# 2025-09-04 14:40:42 INFO src distmod_4 done in 124.262s
# 2025-09-04 14:41:42 INFO src [Eval] thr=0.676, hidden=114, k=5, MRE=0.518868
# 2025-09-04 14:41:42 INFO src [Eval] thr=0.676, hidden=114, k=5, MRE=1.242601
# 2025-09-04 14:41:42 INFO src [Eval] thr=0.676, hidden=114, k=5, MRE=0.664176
# 2025-09-04 14:41:42 INFO src [Eval] thr=0.676, hidden=114, k=5, MRE=0.017702
# 2025-09-04 14:41:42 INFO src
# 2025-09-04 14:41:42 INFO src distmod_4 done in 101.684s
# 2025-09-04 14:41:42 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:41:42 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:41:42 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:41:42 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:41:42 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:41:43 INFO src iter=10 evals_total=55 best_current=[0.175112,0.075876,0.175419,0.000959] dt_iter=186.130s dt_total=1947.649s
# 2025-09-04 14:41:44 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:41:44 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:41:44 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:41:44 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:43:29 INFO src [Eval] thr=0.853, hidden=144, k=5, MRE=0.508344
# 2025-09-04 14:43:29 INFO src [Eval] thr=0.853, hidden=144, k=5, MRE=1.184766
# 2025-09-04 14:43:29 INFO src [Eval] thr=0.853, hidden=144, k=5, MRE=1.035290
# 2025-09-04 14:43:29 INFO src [Eval] thr=0.853, hidden=144, k=5, MRE=0.015054
# 2025-09-04 14:43:29 INFO src
# 2025-09-04 14:43:29 INFO src distmod_4 done in 104.593s
# 2025-09-04 14:43:29 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:43:33 INFO src [Eval] thr=0.197, hidden=78, k=16, MRE=0.323850
# 2025-09-04 14:43:33 INFO src [Eval] thr=0.197, hidden=78, k=27, MRE=0.564466
# 2025-09-04 14:43:33 INFO src [Eval] thr=0.197, hidden=78, k=16, MRE=0.480749
# 2025-09-04 14:43:33 INFO src [Eval] thr=0.197, hidden=78, k=5, MRE=0.030151
# 2025-09-04 14:43:33 INFO src
# 2025-09-04 14:43:33 INFO src distmod_4 done in 109.383s
# 2025-09-04 14:43:40 INFO src [Eval] thr=0.054, hidden=96, k=35, MRE=0.280444
# 2025-09-04 14:43:40 INFO src [Eval] thr=0.054, hidden=96, k=36, MRE=0.128317
# 2025-09-04 14:43:40 INFO src [Eval] thr=0.054, hidden=96, k=35, MRE=0.654047
# 2025-09-04 14:43:40 INFO src [Eval] thr=0.054, hidden=96, k=34, MRE=0.003895
# 2025-09-04 14:43:40 INFO src
# 2025-09-04 14:43:40 INFO src distmod_4 done in 116.395s
# 2025-09-04 14:43:45 INFO src [Eval] thr=0.639, hidden=191, k=5, MRE=0.737945
# 2025-09-04 14:43:45 INFO src [Eval] thr=0.639, hidden=191, k=5, MRE=1.278424
# 2025-09-04 14:43:45 INFO src [Eval] thr=0.639, hidden=191, k=5, MRE=0.592132
# 2025-09-04 14:43:45 INFO src [Eval] thr=0.639, hidden=191, k=5, MRE=0.010840
# 2025-09-04 14:43:45 INFO src
# 2025-09-04 14:43:45 INFO src distmod_4 done in 121.083s
# 2025-09-04 14:44:52 INFO src [Eval] thr=0.436, hidden=127, k=5, MRE=0.521168
# 2025-09-04 14:44:52 INFO src [Eval] thr=0.436, hidden=127, k=5, MRE=1.137966
# 2025-09-04 14:44:52 INFO src [Eval] thr=0.436, hidden=127, k=5, MRE=1.508484
# 2025-09-04 14:44:52 INFO src [Eval] thr=0.436, hidden=127, k=5, MRE=0.010367
# 2025-09-04 14:44:52 INFO src
# 2025-09-04 14:44:52 INFO src distmod_4 done in 83.589s
# 2025-09-04 14:44:52 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:44:52 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:44:52 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:44:52 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:44:52 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:44:53 INFO src iter=11 evals_total=60 best_current=[0.175112,0.075876,0.175419,0.000959] dt_iter=190.069s dt_total=2137.721s
# 2025-09-04 14:44:54 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:44:54 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:44:54 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:44:54 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:46:38 INFO src [Eval] thr=0.755, hidden=122, k=5, MRE=0.548784
# 2025-09-04 14:46:38 INFO src [Eval] thr=0.755, hidden=122, k=5, MRE=0.930882
# 2025-09-04 14:46:38 INFO src [Eval] thr=0.755, hidden=122, k=5, MRE=0.587707
# 2025-09-04 14:46:38 INFO src [Eval] thr=0.755, hidden=122, k=5, MRE=0.036923
# 2025-09-04 14:46:38 INFO src
# 2025-09-04 14:46:38 INFO src distmod_4 done in 104.221s
# 2025-09-04 14:46:38 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:46:53 INFO src [Eval] thr=0.306, hidden=150, k=7, MRE=0.506722
# 2025-09-04 14:46:53 INFO src [Eval] thr=0.306, hidden=150, k=10, MRE=0.259523
# 2025-09-04 14:46:53 INFO src [Eval] thr=0.306, hidden=150, k=7, MRE=1.209858
# 2025-09-04 14:46:53 INFO src [Eval] thr=0.306, hidden=150, k=5, MRE=0.013269
# 2025-09-04 14:46:53 INFO src
# 2025-09-04 14:46:53 INFO src distmod_4 done in 119.333s
# 2025-09-04 14:46:53 INFO src [Eval] thr=0.378, hidden=199, k=6, MRE=0.525652
# 2025-09-04 14:46:53 INFO src [Eval] thr=0.378, hidden=199, k=6, MRE=1.265580
# 2025-09-04 14:46:53 INFO src [Eval] thr=0.378, hidden=199, k=6, MRE=1.125243
# 2025-09-04 14:46:53 INFO src [Eval] thr=0.378, hidden=199, k=5, MRE=0.019196
# 2025-09-04 14:46:53 INFO src
# 2025-09-04 14:46:53 INFO src distmod_4 done in 119.416s
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f88e3c5aac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# 2025-09-04 14:46:57 INFO src [Eval] thr=0.249, hidden=199, k=10, MRE=0.329751
# 2025-09-04 14:46:57 INFO src [Eval] thr=0.249, hidden=199, k=14, MRE=0.271569
# 2025-09-04 14:46:57 INFO src [Eval] thr=0.249, hidden=199, k=10, MRE=0.518050
# 2025-09-04 14:46:57 INFO src [Eval] thr=0.249, hidden=199, k=5, MRE=0.019196
# 2025-09-04 14:46:57 INFO src
# 2025-09-04 14:46:57 INFO src distmod_4 done in 122.668s
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fe566f0eac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# 2025-09-04 14:48:03 INFO src [Eval] thr=0.422, hidden=168, k=6, MRE=0.692714
# 2025-09-04 14:48:03 INFO src [Eval] thr=0.422, hidden=168, k=6, MRE=1.770855
# 2025-09-04 14:48:03 INFO src [Eval] thr=0.422, hidden=168, k=6, MRE=0.743540
# 2025-09-04 14:48:03 INFO src [Eval] thr=0.422, hidden=168, k=5, MRE=0.031798
# 2025-09-04 14:48:03 INFO src
# 2025-09-04 14:48:03 INFO src distmod_4 done in 84.947s
# 2025-09-04 14:48:03 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:48:03 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:48:03 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:48:03 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:48:03 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:48:04 INFO src iter=12 evals_total=65 best_current=[0.175112,0.075876,0.175419,0.000959] dt_iter=191.130s dt_total=2328.853s
# 2025-09-04 14:48:32 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:48:32 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:48:32 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:48:32 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:49:57 INFO src [Eval] thr=0.684, hidden=22, k=5, MRE=0.468150
# 2025-09-04 14:49:57 INFO src [Eval] thr=0.684, hidden=22, k=5, MRE=0.866166
# 2025-09-04 14:49:57 INFO src [Eval] thr=0.684, hidden=22, k=5, MRE=0.611635
# 2025-09-04 14:49:57 INFO src [Eval] thr=0.684, hidden=22, k=5, MRE=0.040648
# 2025-09-04 14:49:57 INFO src
# 2025-09-04 14:49:57 INFO src distmod_4 done in 84.894s
# 2025-09-04 14:49:57 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:50:23 INFO src [Eval] thr=0.380, hidden=185, k=6, MRE=0.566808
# 2025-09-04 14:50:23 INFO src [Eval] thr=0.380, hidden=185, k=6, MRE=1.077118
# 2025-09-04 14:50:23 INFO src [Eval] thr=0.380, hidden=185, k=6, MRE=0.835024
# 2025-09-04 14:50:23 INFO src [Eval] thr=0.380, hidden=185, k=5, MRE=0.013274
# 2025-09-04 14:50:23 INFO src
# 2025-09-04 14:50:23 INFO src distmod_4 done in 111.405s
# 2025-09-04 14:50:26 INFO src [Eval] thr=0.684, hidden=90, k=5, MRE=0.448221
# 2025-09-04 14:50:26 INFO src [Eval] thr=0.684, hidden=90, k=5, MRE=1.159598
# 2025-09-04 14:50:26 INFO src [Eval] thr=0.684, hidden=90, k=5, MRE=0.633907
# 2025-09-04 14:50:26 INFO src [Eval] thr=0.684, hidden=90, k=5, MRE=0.012529
# 2025-09-04 14:50:26 INFO src
# 2025-09-04 14:50:26 INFO src distmod_4 done in 113.785s
# 2025-09-04 14:50:28 INFO src [Eval] thr=0.917, hidden=199, k=5, MRE=0.809687
# 2025-09-04 14:50:28 INFO src [Eval] thr=0.917, hidden=199, k=5, MRE=0.798095
# 2025-09-04 14:50:28 INFO src [Eval] thr=0.917, hidden=199, k=5, MRE=0.990389
# 2025-09-04 14:50:28 INFO src [Eval] thr=0.917, hidden=199, k=5, MRE=0.019196
# 2025-09-04 14:50:28 INFO src
# 2025-09-04 14:50:28 INFO src distmod_4 done in 116.478s
# 2025-09-04 14:51:32 INFO src [Eval] thr=0.666, hidden=124, k=5, MRE=0.632430
# 2025-09-04 14:51:32 INFO src [Eval] thr=0.666, hidden=124, k=5, MRE=1.189439
# 2025-09-04 14:51:32 INFO src [Eval] thr=0.666, hidden=124, k=5, MRE=0.540274
# 2025-09-04 14:51:32 INFO src [Eval] thr=0.666, hidden=124, k=5, MRE=0.018149
# 2025-09-04 14:51:32 INFO src
# 2025-09-04 14:51:32 INFO src distmod_4 done in 95.274s
# 2025-09-04 14:51:32 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:51:32 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:51:32 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:51:32 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:51:32 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:51:33 INFO src iter=13 evals_total=70 best_current=[0.175112,0.075876,0.175419,0.000959] dt_iter=208.906s dt_total=2537.826s
# 2025-09-04 14:51:34 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:51:34 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:51:34 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:51:34 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:53:12 INFO src [Eval] thr=0.817, hidden=98, k=5, MRE=0.524051
# 2025-09-04 14:53:12 INFO src [Eval] thr=0.817, hidden=98, k=5, MRE=1.187281
# 2025-09-04 14:53:12 INFO src [Eval] thr=0.817, hidden=98, k=5, MRE=0.629339
# 2025-09-04 14:53:12 INFO src [Eval] thr=0.817, hidden=98, k=5, MRE=0.013149
# 2025-09-04 14:53:12 INFO src
# 2025-09-04 14:53:12 INFO src distmod_4 done in 98.215s
# 2025-09-04 14:53:12 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:53:29 INFO src [Eval] thr=0.352, hidden=98, k=6, MRE=0.505801
# 2025-09-04 14:53:29 INFO src [Eval] thr=0.352, hidden=98, k=7, MRE=0.295091
# 2025-09-04 14:53:29 INFO src [Eval] thr=0.352, hidden=98, k=6, MRE=1.245454
# 2025-09-04 14:53:29 INFO src [Eval] thr=0.352, hidden=98, k=5, MRE=0.013149
# 2025-09-04 14:53:29 INFO src
# 2025-09-04 14:53:29 INFO src distmod_4 done in 114.506s
# 2025-09-04 14:53:31 INFO src [Eval] thr=0.051, hidden=61, k=35, MRE=0.454291
# 2025-09-04 14:53:31 INFO src [Eval] thr=0.051, hidden=61, k=36, MRE=0.061533
# 2025-09-04 14:53:31 INFO src [Eval] thr=0.051, hidden=61, k=35, MRE=0.221509
# 2025-09-04 14:53:31 INFO src [Eval] thr=0.051, hidden=61, k=34, MRE=0.002909
# 2025-09-04 14:53:31 INFO src
# 2025-09-04 14:53:31 INFO src distmod_4 done in 116.817s
# 2025-09-04 14:53:33 INFO src [Eval] thr=0.889, hidden=150, k=5, MRE=0.563904
# 2025-09-04 14:53:33 INFO src [Eval] thr=0.889, hidden=150, k=5, MRE=1.260804
# 2025-09-04 14:53:33 INFO src [Eval] thr=0.889, hidden=150, k=5, MRE=0.513185
# 2025-09-04 14:53:33 INFO src [Eval] thr=0.889, hidden=150, k=5, MRE=0.013269
# 2025-09-04 14:53:33 INFO src
# 2025-09-04 14:53:33 INFO src distmod_4 done in 119.003s
# 2025-09-04 14:54:34 INFO src [Eval] thr=0.527, hidden=102, k=5, MRE=0.507453
# 2025-09-04 14:54:34 INFO src [Eval] thr=0.527, hidden=102, k=5, MRE=0.935963
# 2025-09-04 14:54:34 INFO src [Eval] thr=0.527, hidden=102, k=5, MRE=0.740568
# 2025-09-04 14:54:34 INFO src [Eval] thr=0.527, hidden=102, k=5, MRE=0.019705
# 2025-09-04 14:54:34 INFO src
# 2025-09-04 14:54:34 INFO src distmod_4 done in 81.600s
# 2025-09-04 14:54:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:54:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:54:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:54:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:54:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:54:35 INFO src iter=14 evals_total=75 best_current=[0.175112,0.061533,0.175419,0.000959] dt_iter=181.801s dt_total=2719.628s
# 2025-09-04 14:54:36 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:54:36 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:54:36 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:54:36 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:55:56 INFO src [Eval] thr=0.543, hidden=21, k=5, MRE=0.627294
# 2025-09-04 14:55:56 INFO src [Eval] thr=0.543, hidden=21, k=5, MRE=1.211390
# 2025-09-04 14:55:56 INFO src [Eval] thr=0.543, hidden=21, k=5, MRE=0.957392
# 2025-09-04 14:55:56 INFO src [Eval] thr=0.543, hidden=21, k=5, MRE=0.035144
# 2025-09-04 14:55:56 INFO src
# 2025-09-04 14:55:56 INFO src distmod_4 done in 79.697s
# 2025-09-04 14:55:56 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:56:13 INFO src [Eval] thr=0.873, hidden=44, k=5, MRE=0.557186
# 2025-09-04 14:56:13 INFO src [Eval] thr=0.873, hidden=44, k=5, MRE=0.894778
# 2025-09-04 14:56:13 INFO src [Eval] thr=0.873, hidden=44, k=5, MRE=0.740197
# 2025-09-04 14:56:13 INFO src [Eval] thr=0.873, hidden=44, k=5, MRE=0.014275
# 2025-09-04 14:56:13 INFO src
# 2025-09-04 14:56:13 INFO src distmod_4 done in 96.907s
# 2025-09-04 14:56:15 INFO src [Eval] thr=0.715, hidden=78, k=5, MRE=0.491583
# 2025-09-04 14:56:15 INFO src [Eval] thr=0.715, hidden=78, k=5, MRE=1.099908
# 2025-09-04 14:56:15 INFO src [Eval] thr=0.715, hidden=78, k=5, MRE=0.501030
# 2025-09-04 14:56:15 INFO src [Eval] thr=0.715, hidden=78, k=5, MRE=0.030151
# 2025-09-04 14:56:15 INFO src
# 2025-09-04 14:56:15 INFO src distmod_4 done in 98.567s
# 2025-09-04 14:56:23 INFO src [Eval] thr=0.998, hidden=172, k=5, MRE=0.529190
# 2025-09-04 14:56:23 INFO src [Eval] thr=0.998, hidden=172, k=5, MRE=1.647405
# 2025-09-04 14:56:23 INFO src [Eval] thr=0.998, hidden=172, k=5, MRE=1.410000
# 2025-09-04 14:56:23 INFO src [Eval] thr=0.998, hidden=172, k=5, MRE=0.018576
# 2025-09-04 14:56:23 INFO src
# 2025-09-04 14:56:23 INFO src distmod_4 done in 106.998s
# 2025-09-04 14:57:26 INFO src [Eval] thr=0.782, hidden=79, k=5, MRE=0.462167
# 2025-09-04 14:57:26 INFO src [Eval] thr=0.782, hidden=79, k=5, MRE=1.237781
# 2025-09-04 14:57:26 INFO src [Eval] thr=0.782, hidden=79, k=5, MRE=0.929111
# 2025-09-04 14:57:26 INFO src [Eval] thr=0.782, hidden=79, k=5, MRE=0.048482
# 2025-09-04 14:57:26 INFO src
# 2025-09-04 14:57:26 INFO src distmod_4 done in 89.984s
# 2025-09-04 14:57:26 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:57:26 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:57:26 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:57:26 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:57:26 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 14:57:27 INFO src iter=15 evals_total=80 best_current=[0.175112,0.061533,0.175419,0.000959] dt_iter=171.712s dt_total=2891.343s
# 2025-09-04 14:57:28 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:57:28 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:57:28 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:57:28 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:59:06 INFO src [Eval] thr=0.921, hidden=109, k=5, MRE=0.468063
# 2025-09-04 14:59:06 INFO src [Eval] thr=0.921, hidden=109, k=5, MRE=1.057798
# 2025-09-04 14:59:06 INFO src [Eval] thr=0.921, hidden=109, k=5, MRE=0.578824
# 2025-09-04 14:59:06 INFO src [Eval] thr=0.921, hidden=109, k=5, MRE=0.021510
# 2025-09-04 14:59:06 INFO src
# 2025-09-04 14:59:06 INFO src distmod_4 done in 98.085s
# 2025-09-04 14:59:06 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 14:59:09 INFO src [Eval] thr=0.894, hidden=84, k=5, MRE=0.482226
# 2025-09-04 14:59:09 INFO src [Eval] thr=0.894, hidden=84, k=5, MRE=1.159868
# 2025-09-04 14:59:09 INFO src [Eval] thr=0.894, hidden=84, k=5, MRE=0.607434
# 2025-09-04 14:59:09 INFO src [Eval] thr=0.894, hidden=84, k=5, MRE=0.035966
# 2025-09-04 14:59:09 INFO src
# 2025-09-04 14:59:09 INFO src distmod_4 done in 101.106s
# 2025-09-04 14:59:11 INFO src [Eval] thr=0.810, hidden=119, k=5, MRE=0.692923
# 2025-09-04 14:59:11 INFO src [Eval] thr=0.810, hidden=119, k=5, MRE=1.349782
# 2025-09-04 14:59:11 INFO src [Eval] thr=0.810, hidden=119, k=5, MRE=0.578697
# 2025-09-04 14:59:11 INFO src [Eval] thr=0.810, hidden=119, k=5, MRE=0.024087
# 2025-09-04 14:59:11 INFO src
# 2025-09-04 14:59:11 INFO src distmod_4 done in 103.398s
# 2025-09-04 14:59:17 INFO src [Eval] thr=0.625, hidden=199, k=5, MRE=0.809687
# 2025-09-04 14:59:17 INFO src [Eval] thr=0.625, hidden=199, k=5, MRE=0.798095
# 2025-09-04 14:59:17 INFO src [Eval] thr=0.625, hidden=199, k=5, MRE=0.990389
# 2025-09-04 14:59:17 INFO src [Eval] thr=0.625, hidden=199, k=5, MRE=0.019196
# 2025-09-04 14:59:17 INFO src
# 2025-09-04 14:59:17 INFO src distmod_4 done in 109.595s
# 2025-09-04 15:00:22 INFO src [Eval] thr=0.812, hidden=128, k=5, MRE=0.572247
# 2025-09-04 15:00:22 INFO src [Eval] thr=0.812, hidden=128, k=5, MRE=0.993799
# 2025-09-04 15:00:22 INFO src [Eval] thr=0.812, hidden=128, k=5, MRE=0.578648
# 2025-09-04 15:00:22 INFO src [Eval] thr=0.812, hidden=128, k=5, MRE=0.030456
# 2025-09-04 15:00:22 INFO src
# 2025-09-04 15:00:22 INFO src distmod_4 done in 75.752s
# 2025-09-04 15:00:22 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:00:22 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:00:22 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:00:22 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:00:22 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:00:22 INFO src iter=16 evals_total=85 best_current=[0.175112,0.061533,0.175419,0.000959] dt_iter=175.713s dt_total=3067.059s
# 2025-09-04 15:00:23 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:00:23 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:00:23 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:00:23 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:02:19 INFO src [Eval] thr=0.422, hidden=133, k=6, MRE=0.580235
# 2025-09-04 15:02:19 INFO src [Eval] thr=0.422, hidden=133, k=6, MRE=0.945886
# 2025-09-04 15:02:19 INFO src [Eval] thr=0.422, hidden=133, k=6, MRE=0.545478
# 2025-09-04 15:02:19 INFO src [Eval] thr=0.422, hidden=133, k=5, MRE=0.032955
# 2025-09-04 15:02:19 INFO src
# 2025-09-04 15:02:19 INFO src distmod_4 done in 115.876s
# 2025-09-04 15:02:19 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:02:20 INFO src [Eval] thr=0.672, hidden=199, k=5, MRE=0.809687
# 2025-09-04 15:02:20 INFO src [Eval] thr=0.672, hidden=199, k=5, MRE=0.798095
# 2025-09-04 15:02:20 INFO src [Eval] thr=0.672, hidden=199, k=5, MRE=0.990389
# 2025-09-04 15:02:20 INFO src [Eval] thr=0.672, hidden=199, k=5, MRE=0.019196
# 2025-09-04 15:02:20 INFO src
# 2025-09-04 15:02:20 INFO src distmod_4 done in 116.390s
# 2025-09-04 15:02:20 INFO src [Eval] thr=0.186, hidden=144, k=18, MRE=0.372421
# 2025-09-04 15:02:20 INFO src [Eval] thr=0.186, hidden=144, k=28, MRE=0.763999
# 2025-09-04 15:02:20 INFO src [Eval] thr=0.186, hidden=144, k=17, MRE=0.262497
# 2025-09-04 15:02:20 INFO src [Eval] thr=0.186, hidden=144, k=5, MRE=0.015054
# 2025-09-04 15:02:20 INFO src
# 2025-09-04 15:02:20 INFO src distmod_4 done in 116.636s
# 2025-09-04 15:02:20 INFO src [Eval] thr=0.309, hidden=177, k=7, MRE=0.579629
# 2025-09-04 15:02:20 INFO src [Eval] thr=0.309, hidden=177, k=10, MRE=0.257798
# 2025-09-04 15:02:20 INFO src [Eval] thr=0.309, hidden=177, k=7, MRE=0.710147
# 2025-09-04 15:02:20 INFO src [Eval] thr=0.309, hidden=177, k=5, MRE=0.012728
# 2025-09-04 15:02:20 INFO src
# 2025-09-04 15:02:20 INFO src distmod_4 done in 116.843s
# 2025-09-04 15:03:41 INFO src [Eval] thr=0.397, hidden=163, k=6, MRE=0.706774
# 2025-09-04 15:03:41 INFO src [Eval] thr=0.397, hidden=163, k=6, MRE=0.848975
# 2025-09-04 15:03:41 INFO src [Eval] thr=0.397, hidden=163, k=6, MRE=0.610955
# 2025-09-04 15:03:41 INFO src [Eval] thr=0.397, hidden=163, k=5, MRE=0.029296
# 2025-09-04 15:03:41 INFO src
# 2025-09-04 15:03:41 INFO src distmod_4 done in 81.428s
# 2025-09-04 15:03:41 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:03:41 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:03:41 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:03:41 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:03:41 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:03:42 INFO src iter=17 evals_total=90 best_current=[0.175112,0.061533,0.175419,0.000959] dt_iter=199.384s dt_total=3266.446s
# 2025-09-04 15:03:43 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:03:43 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:03:43 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:03:43 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:05:03 INFO src [Eval] thr=0.471, hidden=23, k=5, MRE=0.642880
# 2025-09-04 15:05:03 INFO src [Eval] thr=0.471, hidden=23, k=5, MRE=1.231521
# 2025-09-04 15:05:03 INFO src [Eval] thr=0.471, hidden=23, k=5, MRE=0.650268
# 2025-09-04 15:05:03 INFO src [Eval] thr=0.471, hidden=23, k=5, MRE=0.008356
# 2025-09-04 15:05:03 INFO src
# 2025-09-04 15:05:03 INFO src distmod_4 done in 80.284s
# 2025-09-04 15:05:03 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:05:17 INFO src [Eval] thr=0.054, hidden=40, k=35, MRE=0.356065
# 2025-09-04 15:05:17 INFO src [Eval] thr=0.054, hidden=40, k=36, MRE=0.128044
# 2025-09-04 15:05:17 INFO src [Eval] thr=0.054, hidden=40, k=35, MRE=0.220381
# 2025-09-04 15:05:17 INFO src [Eval] thr=0.054, hidden=40, k=34, MRE=0.002665
# 2025-09-04 15:05:17 INFO src
# 2025-09-04 15:05:17 INFO src distmod_4 done in 94.682s
# 2025-09-04 15:05:23 INFO src [Eval] thr=0.662, hidden=89, k=5, MRE=0.462214
# 2025-09-04 15:05:23 INFO src [Eval] thr=0.662, hidden=89, k=5, MRE=1.185630
# 2025-09-04 15:05:23 INFO src [Eval] thr=0.662, hidden=89, k=5, MRE=0.554107
# 2025-09-04 15:05:23 INFO src [Eval] thr=0.662, hidden=89, k=5, MRE=0.017171
# 2025-09-04 15:05:23 INFO src
# 2025-09-04 15:05:23 INFO src distmod_4 done in 100.532s
# 2025-09-04 15:05:25 INFO src [Eval] thr=0.235, hidden=68, k=12, MRE=0.790778
# 2025-09-04 15:05:25 INFO src [Eval] thr=0.235, hidden=68, k=17, MRE=0.274449
# 2025-09-04 15:05:25 INFO src [Eval] thr=0.235, hidden=68, k=11, MRE=0.374304
# 2025-09-04 15:05:25 INFO src [Eval] thr=0.235, hidden=68, k=5, MRE=0.017434
# 2025-09-04 15:05:25 INFO src
# 2025-09-04 15:05:25 INFO src distmod_4 done in 101.924s
# 2025-09-04 15:06:30 INFO src [Eval] thr=0.356, hidden=55, k=6, MRE=0.540071
# 2025-09-04 15:06:30 INFO src [Eval] thr=0.356, hidden=55, k=6, MRE=1.222796
# 2025-09-04 15:06:30 INFO src [Eval] thr=0.356, hidden=55, k=6, MRE=0.666897
# 2025-09-04 15:06:30 INFO src [Eval] thr=0.356, hidden=55, k=5, MRE=0.021304
# 2025-09-04 15:06:30 INFO src
# 2025-09-04 15:06:30 INFO src distmod_4 done in 87.266s
# 2025-09-04 15:06:30 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:06:30 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:06:30 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:06:30 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:06:30 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:06:32 INFO src iter=18 evals_total=95 best_current=[0.175112,0.061533,0.175419,0.000959] dt_iter=169.703s dt_total=3436.151s
# 2025-09-04 15:06:33 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:06:33 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:06:33 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:06:33 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:08:08 INFO src [Eval] thr=0.417, hidden=94, k=6, MRE=0.778637
# 2025-09-04 15:08:08 INFO src [Eval] thr=0.417, hidden=94, k=6, MRE=1.159457
# 2025-09-04 15:08:08 INFO src [Eval] thr=0.417, hidden=94, k=6, MRE=0.638733
# 2025-09-04 15:08:08 INFO src [Eval] thr=0.417, hidden=94, k=5, MRE=0.031191
# 2025-09-04 15:08:08 INFO src
# 2025-09-04 15:08:08 INFO src distmod_4 done in 95.322s
# 2025-09-04 15:08:08 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:08:22 INFO src [Eval] thr=0.819, hidden=145, k=5, MRE=0.660457
# 2025-09-04 15:08:22 INFO src [Eval] thr=0.819, hidden=145, k=5, MRE=1.175692
# 2025-09-04 15:08:22 INFO src [Eval] thr=0.819, hidden=145, k=5, MRE=0.519068
# 2025-09-04 15:08:22 INFO src [Eval] thr=0.819, hidden=145, k=5, MRE=0.027967
# 2025-09-04 15:08:22 INFO src
# 2025-09-04 15:08:22 INFO src distmod_4 done in 109.443s
# 2025-09-04 15:08:24 INFO src [Eval] thr=0.550, hidden=153, k=5, MRE=0.773607
# 2025-09-04 15:08:24 INFO src [Eval] thr=0.550, hidden=153, k=5, MRE=1.322506
# 2025-09-04 15:08:24 INFO src [Eval] thr=0.550, hidden=153, k=5, MRE=0.523993
# 2025-09-04 15:08:24 INFO src [Eval] thr=0.550, hidden=153, k=5, MRE=0.024786
# 2025-09-04 15:08:24 INFO src
# 2025-09-04 15:08:24 INFO src distmod_4 done in 111.265s
# 2025-09-04 15:08:25 INFO src [Eval] thr=0.115, hidden=64, k=30, MRE=0.174976
# 2025-09-04 15:08:25 INFO src [Eval] thr=0.115, hidden=64, k=32, MRE=0.132929
# 2025-09-04 15:08:25 INFO src [Eval] thr=0.115, hidden=64, k=28, MRE=0.321617
# 2025-09-04 15:08:25 INFO src [Eval] thr=0.115, hidden=64, k=17, MRE=0.015134
# 2025-09-04 15:08:25 INFO src
# 2025-09-04 15:08:25 INFO src distmod_4 done in 112.271s
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f2a23eaaac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# 2025-09-04 15:09:33 INFO src [Eval] thr=0.475, hidden=114, k=5, MRE=0.518868
# 2025-09-04 15:09:33 INFO src [Eval] thr=0.475, hidden=114, k=5, MRE=1.242601
# 2025-09-04 15:09:33 INFO src [Eval] thr=0.475, hidden=114, k=5, MRE=0.664176
# 2025-09-04 15:09:33 INFO src [Eval] thr=0.475, hidden=114, k=5, MRE=0.017702
# 2025-09-04 15:09:33 INFO src
# 2025-09-04 15:09:33 INFO src distmod_4 done in 85.600s
# 2025-09-04 15:09:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:09:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:09:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:09:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:09:34 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:09:35 INFO src iter=19 evals_total=100 best_current=[0.174976,0.061533,0.175419,0.000959] dt_iter=183.595s dt_total=3619.748s
# 2025-09-04 15:09:49 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:09:49 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:09:49 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:09:49 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:11:15 INFO src [Eval] thr=0.840, hidden=19, k=5, MRE=0.474852
# 2025-09-04 15:11:15 INFO src [Eval] thr=0.840, hidden=19, k=5, MRE=0.860033
# 2025-09-04 15:11:15 INFO src [Eval] thr=0.840, hidden=19, k=5, MRE=0.562886
# 2025-09-04 15:11:15 INFO src [Eval] thr=0.840, hidden=19, k=5, MRE=0.031221
# 2025-09-04 15:11:15 INFO src
# 2025-09-04 15:11:15 INFO src distmod_4 done in 85.514s
# 2025-09-04 15:11:15 INFO src distmod_4 start n=1 targets=4
# 2025-09-04 15:11:17 INFO src [Eval] thr=0.349, hidden=56, k=6, MRE=0.628415
# 2025-09-04 15:11:17 INFO src [Eval] thr=0.349, hidden=56, k=8, MRE=0.302321
# 2025-09-04 15:11:17 INFO src [Eval] thr=0.349, hidden=56, k=6, MRE=0.699750
# 2025-09-04 15:11:17 INFO src [Eval] thr=0.349, hidden=56, k=5, MRE=0.018281
# 2025-09-04 15:11:17 INFO src
# 2025-09-04 15:11:17 INFO src distmod_4 done in 87.608s
# 2025-09-04 15:11:31 INFO src [Eval] thr=0.795, hidden=104, k=5, MRE=0.467355
# 2025-09-04 15:11:31 INFO src [Eval] thr=0.795, hidden=104, k=5, MRE=1.358203
# 2025-09-04 15:11:31 INFO src [Eval] thr=0.795, hidden=104, k=5, MRE=0.610378
# 2025-09-04 15:11:31 INFO src [Eval] thr=0.795, hidden=104, k=5, MRE=0.039132
# 2025-09-04 15:11:31 INFO src
# 2025-09-04 15:11:31 INFO src distmod_4 done in 101.706s
# 2025-09-04 15:11:43 INFO src [Eval] thr=0.053, hidden=163, k=35, MRE=0.413275
# 2025-09-04 15:11:43 INFO src [Eval] thr=0.053, hidden=163, k=36, MRE=0.093071
# 2025-09-04 15:11:43 INFO src [Eval] thr=0.053, hidden=163, k=35, MRE=0.773017
# 2025-09-04 15:11:43 INFO src [Eval] thr=0.053, hidden=163, k=34, MRE=0.009323
# 2025-09-04 15:11:43 INFO src
# 2025-09-04 15:11:43 INFO src distmod_4 done in 113.342s
# 2025-09-04 15:12:35 INFO src [Eval] thr=0.509, hidden=86, k=5, MRE=0.613929
# 2025-09-04 15:12:35 INFO src [Eval] thr=0.509, hidden=86, k=5, MRE=1.315269
# 2025-09-04 15:12:35 INFO src [Eval] thr=0.509, hidden=86, k=5, MRE=0.602795
# 2025-09-04 15:12:35 INFO src [Eval] thr=0.509, hidden=86, k=5, MRE=0.039716
# 2025-09-04 15:12:35 INFO src
# 2025-09-04 15:12:35 INFO src distmod_4 done in 79.942s
# 2025-09-04 15:12:35 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:12:35 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:12:35 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:12:35 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:12:35 DEBUG src ref_model_zero called batch=1 splits=4
# 2025-09-04 15:12:37 INFO src iter=20 evals_total=105 best_current=[0.174976,0.061533,0.175419,0.000959] dt_iter=181.396s dt_total=3801.148s
# 2025-09-04 15:12:37 INFO src optimizer_vpbo done total_evals=105 total_time=3801.150s
# human health - total thr 0.115 hidden 64 MRE 0.17497553262573828
# ecosystem quality - total thr 0.051 hidden 61 MRE 0.06153304979034109
# resources - total thr 0.007 hidden 14 MRE 0.17541930694831517
# Cost thr 0.007 hidden 14 MRE 0.0009590915948563529
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f56190feac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fe600ebaac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fe59252aac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f17c630aac0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/conda/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes

# %% [markdown]
# # Final Selected Features

# %%
from src import dcor_filter

import numpy as np

def selected_feature_names(X, y, feature_names, threshold, min_features=5):
    Xf, mask, corr = dcor_filter(X, y, threshold=threshold, min_features=min_features)
    return [name for name, keep in zip(feature_names, mask) if keep]

# If you want names per target (no averaging), use:
def selected_names_per_target(X, Y, feature_names, threshold, min_features=5):
    return {
        t: selected_feature_names(X, Y[:, t], feature_names, threshold, min_features)
        for t in range(Y.shape[1])
    }

# If you want a single “collective” set (averaging across targets), pass Y (2D):
names_human_health = selected_feature_names(X, Y[:,0], selected_features, threshold=0.027, min_features=5)
names_cost = selected_feature_names(X, Y[:,3], selected_features, threshold=0.019, min_features=5)
names_ecosystem = selected_feature_names(X, Y[:,1], selected_features, threshold=0.022, min_features=5)
names_resources = selected_feature_names(X, Y[:,2], selected_features, threshold=0.216, min_features=5)

# Example:
# feature_names = ["f1","f2","f3",...]
# names_human = selected_feature_names(X, Y[:,0], feature_names, threshold=0.1)
# names_collective = selected_feature_names(X, Y, feature_names, threshold=0.1)

# %%
names_human_health,  names_ecosystem, names_resources, names_cost
# Out:
# (['surfaceProcessingLocationCavity',
#   'hotRunner',
#   'hotRunnerCost',
#   'manufacturingCost',
#   'mouldValidationCost',
#   'designTime',
#   'hourlyDesignCost',
#   'removedChassis',
#   'surfaceProcessingLocationChassis',
#   'removedCavity',
#   'numberOfCavities',
#   'totalDistance',
#   'injectedMaterial_product',
#   'injectedMaterialCost',
#   'percentageRecycledMaterial',
#   'maxDepth',
#   'maxWallThickness',
#   'productVolume',
#   'materozzaVolume',
#   'nProdottiAnno',
#   'materialDensity',
#   'tolerance',
#   'surfaceFinishing',
#   'machineCycleTime',
#   'maintenanceCost',
#   'productionCost',
#   'injectedMaterial_materozza',
#   'injectionMouldingProcess',
#   'steelPrice',
#   'mouldMaterialName',
#   'machineName',
#   'EUUSMacchina',
#   'CNMacchina',
#   'setupTime',
#   'deliveryVolume',
#   'deliveryPeriod'],
#  ['surfaceProcessingLocationCavity',
#   'hotRunner',
#   'hotRunnerCost',
#   'manufacturingCost',
#   'mouldValidationCost',
#   'designTime',
#   'hourlyDesignCost',
#   'removedChassis',
#   'surfaceProcessingLocationChassis',
#   'removedCavity',
#   'numberOfCavities',
#   'totalDistance',
#   'injectedMaterial_product',
#   'injectedMaterialCost',
#   'percentageRecycledMaterial',
#   'maxDepth',
#   'maxWallThickness',
#   'productVolume',
#   'materozzaVolume',
#   'nProdottiAnno',
#   'materialDensity',
#   'tolerance',
#   'surfaceFinishing',
#   'machineCycleTime',
#   'maintenanceCost',
#   'productionCost',
#   'injectedMaterial_materozza',
#   'injectionMouldingProcess',
#   'steelPrice',
#   'mouldMaterialName',
#   'machineName',
#   'EUUSMacchina',
#   'CNMacchina',
#   'setupTime',
#   'deliveryVolume',
#   'deliveryPeriod'],
#  ['manufacturingCost',
#   'materozzaVolume',
#   'nProdottiAnno',
#   'tolerance',
#   'surfaceFinishing',
#   'machineCycleTime',
#   'maintenanceCost',
#   'productionCost',
#   'steelPrice',
#   'setupTime',
#   'deliveryVolume',
#   'deliveryPeriod'],
#  ['surfaceProcessingLocationCavity',
#   'hotRunner',
#   'hotRunnerCost',
#   'manufacturingCost',
#   'mouldValidationCost',
#   'designTime',
#   'hourlyDesignCost',
#   'removedChassis',
#   'surfaceProcessingLocationChassis',
#   'removedCavity',
#   'numberOfCavities',
#   'totalDistance',
#   'injectedMaterial_product',
#   'injectedMaterialCost',
#   'percentageRecycledMaterial',
#   'maxDepth',
#   'maxWallThickness',
#   'productVolume',
#   'materozzaVolume',
#   'nProdottiAnno',
#   'materialDensity',
#   'tolerance',
#   'surfaceFinishing',
#   'machineCycleTime',
#   'maintenanceCost',
#   'productionCost',
#   'injectedMaterial_materozza',
#   'injectionMouldingProcess',
#   'steelPrice',
#   'mouldMaterialName',
#   'machineName',
#   'EUUSMacchina',
#   'CNMacchina',
#   'setupTime',
#   'deliveryVolume',
#   'deliveryPeriod'])
